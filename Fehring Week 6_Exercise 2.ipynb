# %% [markdown]
# # Week 6 Exercise 2

# %% [markdown]
# This notebook is derived from Eric Kansa's found here (https://github.com/ekansa/open-context-jupyter). This is going to demonstrate how to access Open Context's API and introduce you to data structures we haven't really encountered. You'll be returning a JSON with this activity, a format that is language-neutral and is great for dealing with data structured in a nested, hierarchical way. This API is accessed with Python, a programming language we haven't really used. Luckily, all you'll have to do is copy and paste the code - but as you're copy and pasting, remember to actually inspect the code and try to see if you can understand what each part of the code is doing.

# %% [markdown]
# When using this notebook, you'll see text instructions like our typical exercises. We'll use the benefit of Jupyter notebooks to interserpse code into these instructions, and you'll be able to do the activity right here! When you want to add a code, remember to just click on the + symbol in the toolbar above - this will start a new line (which will default to code).

# %% [markdown]
# 1. First thing we'll do is make the Request module available. This will allows us to send HTTP requests using Python.
#
# `import requests`

# %%
import requests

# %% [markdown]
# 2. Then we'll create a variable called "api_search_url" and give it a value. Note that the value we're using is the Open Context search, returning a JSON.
#
# `api_search_url = 'https://opencontext.org/search/.json?'`

# %%
api_search_url = 'https://opencontext.org/search/.json?'

# %% [markdown]
# 3. Now we'll create a dictionary in Python - these are unordered data values that are formatted in key:value pairs. In this case, we are creating a parameter for the Open Context search to just Roman data.
#
# params = {
#         'q': 'roman'
#
# }

# %%
params = { 'q': 'roman'}

# %% [markdown]
# 4. We can check to make sure we got the dictionary right.
#
# `params`

# %%
params
# Out:
# {'q': 'roman'}

# %% [markdown]
# 5. We will now create a variable that stores the request to the Open Context API with the parameters we've set up
#
# `response = requests.get(api_search_url, params=params)`

# %%
response = requests.get(api_search_url, params=params)

# %% [markdown]
# 6. This next command shows us the url that is sent to the API
#
# `print('Here\'s the formatted url that gets sent to the Open Context API:\n{}\n'.format(response.url))`

# %%
print('Here\'s the formatted url that gets sent to the Open Context API:\n{}\n'.format(response.url))
# Out:
# Here's the formatted url that gets sent to the Open Context API:
# https://opencontext.org/search/.json?q=roman

# %% [markdown]
# 7. And this command checks the status code of the response to make sure no errors occurred.
#
# `if response.status_code == requests.codes.ok:
#     print('All ok')
# elif response.status_code == 403:
#     print('There was an authentication error. Did you paste your API above?')
# else:
#     print('There was a problem. Error code: {}'.format(response.status_code))
#     print('Try running this cell again.')`

# %%
if response.status_code == requests.codes.ok:
    print('All ok')
elif response.status_code == 403:
    print('There was an authentication error. Did you paste your API above?')
else:
    print('There was a problem. Error code: {}'.format(response.status_code))
    print('Try running this cell again.')
# Out:
# All ok

# %% [markdown]
# 8. To get the API's JSON results (what we asked it to grab), we'll create a variable called "data." Then see what the JSON data looks like.
#
# `data = response.json()`
#
# `data`

# %%
data = response.json()

data
# Out:
# {'@context': ['https://opencontext.org/contexts/search.json',
#   'http://geojson.org/geojson-ld/geojson-context.jsonld'],
#  'id': 'http://opencontext.org/search/.json?q=roman',
#  'label': 'Open Context API',
#  'dcmi:modified': '2019-12-04T22:10:19Z',
#  'dcmi:created': '2019-11-06T05:10:54Z',
#  'oai-pmh:earliestDatestamp': '2006-02-28T00:00:00Z',
#  'start': '-336999',
#  'stop': '2015',
#  'dc-terms:temporal': '-336999/2015',
#  'totalResults': 77460,
#  'startIndex': 0,
#  'itemsPerPage': 20,
#  'next': 'https://opencontext.org/search/?q=roman&rows=20&start=20',
#  'next-json': 'https://opencontext.org/search/.json?q=roman&rows=20&start=20',
#  'last': 'https://opencontext.org/search/?q=roman&rows=20&start=77440',
#  'last-json': 'https://opencontext.org/search/.json?q=roman&rows=20&start=77440',
#  'oc-api:active-sorting': [{'id': '#current-sort-1',
#    'type': 'oc-api:interest-score',
#    'label': 'Interest score',
#    'oc-api:sort-order': 'descending'}],
#  'oc-api:has-sorting': [{'id': 'https://opencontext.org/search/?q=roman&sort=item--asc',
#    'json': 'https://opencontext.org/search/.json?q=roman&sort=item--asc',
#    'type': 'oc-api:sort-item',
#    'label': 'Item (type, provenance, label)',
#    'oc-api:sort-order': 'ascending'},
#   {'id': 'https://opencontext.org/search/?q=roman&sort=item--desc',
#    'json': 'https://opencontext.org/search/.json?q=roman&sort=item--desc',
#    'type': 'oc-api:sort-item',
#    'label': 'Item (type, provenance, label)',
#    'oc-api:sort-order': 'descending'},
#   {'id': 'https://opencontext.org/search/?q=roman&sort=updated--asc',
#    'json': 'https://opencontext.org/search/.json?q=roman&sort=updated--asc',
#    'type': 'oc-api:sort-updated',
#    'label': 'Updated',
#    'oc-api:sort-order': 'ascending'},
#   {'id': 'https://opencontext.org/search/?q=roman&sort=updated--desc',
#    'json': 'https://opencontext.org/search/.json?q=roman&sort=updated--desc',
#    'type': 'oc-api:sort-updated',
#    'label': 'Updated',
#    'oc-api:sort-order': 'descending'}],
#  'oc-api:active-filters': [{'id': '#filter-1',
#    'oc-api:filter': 'Current Text Search Filter',
#    'label': "Search Term: 'roman'",
#    'oc-api:remove': 'https://opencontext.org/search/',
#    'oc-api:remove-json': 'https://opencontext.org/search/.json'}],
#  'oc-api:has-text-search': [{'id': '#textfield-keyword-search',
#    'label': 'Filter by Text Search',
#    'oc-api:search-term': 'roman',
#    'oc-api:template': 'https://opencontext.org/search/?q={SearchTerm}',
#    'oc-api:template-json': 'https://opencontext.org/search/.json?q={SearchTerm}'}],
#  'oc-api:has-form-use-life-ranges': [{'id': 'https://opencontext.org/search/?form-chronotile=10M-0000100010101&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000100010101&q=roman',
#    'count': 2,
#    'category': 'oc-api:chrono-facet',
#    'start': '-337404',
#    'stop': '1950',
#    'properties': {'early bce/ce': -337405, 'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000001002013&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000001002013&q=roman',
#    'count': 1,
#    'category': 'oc-api:chrono-facet',
#    'start': '-81057',
#    'stop': '-9035',
#    'properties': {'early bce/ce': -81058, 'late bce/ce': -9036}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000001101&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000001101&q=roman',
#    'count': 2,
#    'category': 'oc-api:chrono-facet',
#    'start': '-15139',
#    'stop': '1950',
#    'properties': {'early bce/ce': -15140, 'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000001021&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000001021&q=roman',
#    'count': 1,
#    'category': 'oc-api:chrono-facet',
#    'start': '-10256',
#    'stop': '-0490',
#    'properties': {'early bce/ce': -10257, 'late bce/ce': -491}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000111&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000111&q=roman',
#    'count': 3,
#    'category': 'oc-api:chrono-facet',
#    'start': '-7815',
#    'stop': '1950',
#    'properties': {'early bce/ce': -7816, 'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000112&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000112&q=roman',
#    'count': 6,
#    'category': 'oc-api:chrono-facet',
#    'start': '-6594',
#    'stop': '0729',
#    'properties': {'early bce/ce': -6595, 'late bce/ce': 729}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000330&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000330&q=roman',
#    'count': 131,
#    'category': 'oc-api:chrono-facet',
#    'start': '-6594',
#    'stop': '-5373',
#    'properties': {'early bce/ce': -6595, 'late bce/ce': -5374}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000100&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000100&q=roman',
#    'count': 59,
#    'category': 'oc-api:chrono-facet',
#    'start': '-4153',
#    'stop': '1950',
#    'properties': {'early bce/ce': -4154, 'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000120&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000120&q=roman',
#    'count': 5,
#    'category': 'oc-api:chrono-facet',
#    'start': '-4153',
#    'stop': '-0490',
#    'properties': {'early bce/ce': -4154, 'late bce/ce': -491}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000122&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000122&q=roman',
#    'count': 6,
#    'category': 'oc-api:chrono-facet',
#    'start': '-4153',
#    'stop': '-1711',
#    'properties': {'early bce/ce': -4154, 'late bce/ce': -1712}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000011&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000011&q=roman',
#    'count': 5,
#    'category': 'oc-api:chrono-facet',
#    'start': '-2932',
#    'stop': '1950',
#    'properties': {'early bce/ce': -2933, 'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000031&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000031&q=roman',
#    'count': 4,
#    'category': 'oc-api:chrono-facet',
#    'start': '-2932',
#    'stop': '-0490',
#    'properties': {'early bce/ce': -2933, 'late bce/ce': -491}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000010&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000010&q=roman',
#    'count': 5071,
#    'category': 'oc-api:chrono-facet',
#    'start': '-1711',
#    'stop': '1950',
#    'properties': {'early bce/ce': -1712, 'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000012&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000012&q=roman',
#    'count': 3818,
#    'category': 'oc-api:chrono-facet',
#    'start': '-1711',
#    'stop': '0729',
#    'properties': {'early bce/ce': -1712, 'late bce/ce': 729}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000030&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000030&q=roman',
#    'count': 149,
#    'category': 'oc-api:chrono-facet',
#    'start': '-1711',
#    'stop': '-0490',
#    'properties': {'early bce/ce': -1712, 'late bce/ce': -491}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000001&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000001&q=roman',
#    'count': 59097,
#    'category': 'oc-api:chrono-facet',
#    'start': '-0490',
#    'stop': '1950',
#    'properties': {'early bce/ce': -491, 'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000003&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000003&q=roman',
#    'count': 5732,
#    'category': 'oc-api:chrono-facet',
#    'start': '-0490',
#    'stop': '0729',
#    'properties': {'early bce/ce': -491, 'late bce/ce': 729}},
#   {'id': 'https://opencontext.org/search/?form-chronotile=10M-0000000000000&q=roman',
#    'json': 'https://opencontext.org/search/.json?form-chronotile=10M-0000000000000&q=roman',
#    'count': 251,
#    'category': 'oc-api:chrono-facet',
#    'start': '0729',
#    'stop': '1950',
#    'properties': {'early bce/ce': 729, 'late bce/ce': 1950}}],
#  'oc-api:max-disc-tile-zoom': 20,
#  'oc-api:response-tile-zoom': 6,
#  'oc-api:geotile-scope': None,
#  'oc-api:has-facets': [{'id': '#facet-context',
#    'rdfs:isDefinedBy': 'oc-api:facet-context',
#    'label': 'Context',
#    'data-type': 'id',
#    'type': 'oc-api:facet-context',
#    'oc-api:has-id-options': [{'id': 'https://opencontext.org/search/Turkey?q=roman',
#      'json': 'https://opencontext.org/search/Turkey.json?q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/subjects/1_Global_Spatial',
#      'label': 'Turkey',
#      'count': 52876,
#      'slug': 'turkey'},
#     {'id': 'https://opencontext.org/search/Cyprus?q=roman',
#      'json': 'https://opencontext.org/search/Cyprus.json?q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/subjects/67D9F00D-14E6-4A1B-3A61-EC92FC774098',
#      'label': 'Cyprus',
#      'count': 8822,
#      'slug': 'cyprus'},
#     {'id': 'https://opencontext.org/search/Italy?q=roman',
#      'json': 'https://opencontext.org/search/Italy.json?q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/subjects/B66A08F2-5D96-4DD4-1AB1-32880C9A8D9D',
#      'label': 'Italy',
#      'count': 5065,
#      'slug': 'italy'},
#     {'id': 'https://opencontext.org/search/Jordan?q=roman',
#      'json': 'https://opencontext.org/search/Jordan.json?q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/subjects/D9AE02E5-C3F3-41D0-EB3A-39798F63GGGG',
#      'label': 'Jordan',
#      'count': 2777,
#      'slug': 'jordan'},
#     {'id': 'https://opencontext.org/search/Germany?q=roman',
#      'json': 'https://opencontext.org/search/Germany.json?q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/subjects/2_Global_Germany',
#      'label': 'Germany',
#      'count': 457,
#      'slug': 'germany'},
#     {'id': 'https://opencontext.org/search/Egypt?q=roman',
#      'json': 'https://opencontext.org/search/Egypt.json?q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/subjects/A2257E54-3B4F-4DA5-0E50-A428ECEB47A2',
#      'label': 'Egypt',
#      'count': 179,
#      'slug': 'egypt'},
#     {'id': 'https://opencontext.org/search/Israel?q=roman',
#      'json': 'https://opencontext.org/search/Israel.json?q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/subjects/3_Global_Israel',
#      'label': 'Israel',
#      'count': 79,
#      'slug': 'israel'},
#     {'id': 'https://opencontext.org/search/Palestinian+Authority?q=roman',
#      'json': 'https://opencontext.org/search/Palestinian+Authority.json?q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/subjects/4_global_Palestine',
#      'label': 'Palestinian Authority',
#      'count': 39,
#      'slug': 'palestinian-authority'},
#     {'id': 'https://opencontext.org/search/Poland?q=roman',
#      'json': 'https://opencontext.org/search/Poland.json?q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/subjects/a2f952b7-baef-49d8-9cfb-c32a630ac64e',
#      'label': 'Poland',
#      'count': 39,
#      'slug': 'poland'},
#     {'id': 'https://opencontext.org/search/Spain?q=roman',
#      'json': 'https://opencontext.org/search/Spain.json?q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/subjects/3776e3e7-91ea-4c35-9481-0b1fae3afa9a',
#      'label': 'Spain',
#      'count': 28,
#      'slug': 'spain'},
#     {'id': 'https://opencontext.org/search/United+States?q=roman',
#      'json': 'https://opencontext.org/search/United+States.json?q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/subjects/2A1B75E6-8C79-49B9-873A-A2E006669691',
#      'label': 'United States',
#      'count': 12,
#      'slug': 'united-states'},
#     {'id': 'https://opencontext.org/search/Mexico?q=roman',
#      'json': 'https://opencontext.org/search/Mexico.json?q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/subjects/ee431393-7ab1-4d7a-abec-bb05f53babda',
#      'label': 'Mexico',
#      'count': 1,
#      'slug': 'mexico'}]},
#   {'id': '#facet-item-type',
#    'rdfs:isDefinedBy': 'oc-api:facet-item-type',
#    'label': 'Open Context Type',
#    'data-type': 'id',
#    'type': 'oc-api:facet-item-type',
#    'oc-api:has-id-options': [{'id': 'https://opencontext.org/search/?q=roman&type=subjects',
#      'json': 'https://opencontext.org/search/.json?q=roman&type=subjects',
#      'rdfs:isDefinedBy': 'oc-gen:subjects',
#      'label': 'Subjects',
#      'count': 57603,
#      'slug': 'subjects'},
#     {'id': 'https://opencontext.org/search/?q=roman&type=media',
#      'json': 'https://opencontext.org/search/.json?q=roman&type=media',
#      'rdfs:isDefinedBy': 'oc-gen:media',
#      'label': 'Media',
#      'count': 13703,
#      'slug': 'media'},
#     {'id': 'https://opencontext.org/search/?q=roman&type=types',
#      'json': 'https://opencontext.org/search/.json?q=roman&type=types',
#      'rdfs:isDefinedBy': 'oc-gen:types',
#      'label': 'Descriptive types',
#      'count': 4341,
#      'slug': 'types'},
#     {'id': 'https://opencontext.org/search/?q=roman&type=predicates',
#      'json': 'https://opencontext.org/search/.json?q=roman&type=predicates',
#      'rdfs:isDefinedBy': 'oc-gen:predicates',
#      'label': 'Predicates or properties',
#      'count': 1008,
#      'slug': 'predicates'},
#     {'id': 'https://opencontext.org/search/?q=roman&type=documents',
#      'json': 'https://opencontext.org/search/.json?q=roman&type=documents',
#      'rdfs:isDefinedBy': 'oc-gen:documents',
#      'label': 'Documents',
#      'count': 526,
#      'slug': 'documents'},
#     {'id': 'https://opencontext.org/search/?q=roman&type=persons',
#      'json': 'https://opencontext.org/search/.json?q=roman&type=persons',
#      'rdfs:isDefinedBy': 'oc-gen:persons',
#      'label': 'Persons or Organizations',
#      'count': 261,
#      'slug': 'persons'},
#     {'id': 'https://opencontext.org/search/?q=roman&type=projects',
#      'json': 'https://opencontext.org/search/.json?q=roman&type=projects',
#      'rdfs:isDefinedBy': 'oc-gen:projects',
#      'label': 'Projects or Collections',
#      'count': 16,
#      'slug': 'projects'},
#     {'id': 'https://opencontext.org/search/?q=roman&type=tables',
#      'json': 'https://opencontext.org/search/.json?q=roman&type=tables',
#      'rdfs:isDefinedBy': 'oc-gen:tables',
#      'label': 'Tables',
#      'count': 2,
#      'slug': 'tables'}]},
#   {'id': '#facet-prop-oc-gen-subjects',
#    'rdfs:isDefinedBy': 'http://opencontext.org/vocabularies/oc-general/subjects',
#    'label': '(Related) Subjects',
#    'slug': 'rel--oc-gen-subjects',
#    'data-type': 'id',
#    'type': 'oc-api:facet-prop',
#    'oc-api:has-id-options': [{'id': 'https://opencontext.org/search/?prop=rel--oc-gen-cat-loc-or-context&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=rel--oc-gen-cat-loc-or-context&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/vocabularies/oc-general/cat-loc-or-context',
#      'label': 'Location or Context',
#      'count': 7858,
#      'slug': 'rel--oc-gen-cat-loc-or-context'},
#     {'id': 'https://opencontext.org/search/?prop=rel--oc-gen-cat-object&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=rel--oc-gen-cat-object&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/vocabularies/oc-general/cat-object',
#      'label': 'Object',
#      'count': 3255,
#      'slug': 'rel--oc-gen-cat-object'},
#     {'id': 'https://opencontext.org/search/?prop=rel--oc-gen-cat-sample-col&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=rel--oc-gen-cat-sample-col&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/vocabularies/oc-general/cat-sample-col',
#      'label': 'Sample, Collection, or Aggregation',
#      'count': 2090,
#      'slug': 'rel--oc-gen-cat-sample-col'}]},
#   {'id': '#facet-project',
#    'rdfs:isDefinedBy': 'oc-api:facet-project',
#    'label': 'Project',
#    'data-type': 'id',
#    'type': 'oc-api:facet-project',
#    'oc-api:has-id-options': [{'id': 'https://opencontext.org/search/?proj=117-avkat-archaeological-project&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=117-avkat-archaeological-project&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/02b55e8c-e9b1-49e5-8edf-0afeea10e2be',
#      'label': 'Avkat Archaeological Project',
#      'count': 51985,
#      'slug': '117-avkat-archaeological-project'},
#     {'id': 'https://opencontext.org/search/?proj=24-murlo&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=24-murlo&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/DF043419-F23B-41DA-7E4D-EE52AF22F92F',
#      'label': 'Murlo',
#      'count': 9179,
#      'slug': '24-murlo'},
#     {'id': 'https://opencontext.org/search/?proj=42-pyla-koutsopetria-archaeological-project-i-pedestrian&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=42-pyla-koutsopetria-archaeological-project-i-pedestrian&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/3F6DCD13-A476-488E-ED10-47D25513FCB2',
#      'label': 'Pyla-Koutsopetria Archaeological Project I: Pedestrian Survey',
#      'count': 6199,
#      'slug': '42-pyla-koutsopetria-archaeological-project-i-pedestrian'},
#     {'id': 'https://opencontext.org/search/?proj=10-petra-great-temple-excavations&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=10-petra-great-temple-excavations&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/A5DDBEA2-B3C8-43F9-8151-33343CBDC857',
#      'label': 'Petra Great Temple Excavations',
#      'count': 2939,
#      'slug': '10-petra-great-temple-excavations'},
#     {'id': 'https://opencontext.org/search/?proj=125-pyla-koutsopetria-archaeological-project-ii-geophysics&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=125-pyla-koutsopetria-archaeological-project-ii-geophysics&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/b9472eec-e622-4838-b6d8-5a2958b9d4d3',
#      'label': 'Pyla-Koutsopetria Archaeological Project II: Geophysics and Excavation',
#      'count': 2583,
#      'slug': '125-pyla-koutsopetria-archaeological-project-ii-geophysics'},
#     {'id': 'https://opencontext.org/search/?proj=104-the-gabii-project&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=104-the-gabii-project&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd',
#      'label': 'The Gabii Project',
#      'count': 2437,
#      'slug': '104-the-gabii-project'},
#     {'id': 'https://opencontext.org/search/?proj=11-aegean-archaeomalacology&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=11-aegean-archaeomalacology&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/B1DAC335-4DC6-4A57-622E-75BF28BA598D',
#      'label': 'Aegean Archaeomalacology',
#      'count': 977,
#      'slug': '11-aegean-archaeomalacology'},
#     {'id': 'https://opencontext.org/search/?proj=65-biometrical-database-of-european-aurochs-and-domestic-c&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=65-biometrical-database-of-european-aurochs-and-domestic-c&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/1816A043-92E2-471D-A23D-AAC58695D0D3',
#      'label': 'Biometrical Database of European Aurochs and Domestic Cattle',
#      'count': 526,
#      'slug': '65-biometrical-database-of-european-aurochs-and-domestic-c'},
#     {'id': 'https://opencontext.org/search/?proj=101-arce-sphinx-project-1979-1983-archive&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=101-arce-sphinx-project-1979-1983-archive&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9',
#      'label': 'ARCE Sphinx Project 1979-1983 Archive',
#      'count': 184,
#      'slug': '101-arce-sphinx-project-1979-1983-archive'},
#     {'id': 'https://opencontext.org/search/?proj=63-excavations-at-polis&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=63-excavations-at-polis&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/766d9fd5-2175-41e3-b7c9-7eba6777f1f0',
#      'label': 'Excavations at Polis',
#      'count': 138,
#      'slug': '63-excavations-at-polis'},
#     {'id': 'https://opencontext.org/search/?proj=35-catalhoyuk-area-tp-zooarchaeology&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=35-catalhoyuk-area-tp-zooarchaeology&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/02594C48-7497-40D7-11AE-AB942DC513B8',
#      'label': 'Çatalhöyük Area TP Zooarchaeology',
#      'count': 123,
#      'slug': '35-catalhoyuk-area-tp-zooarchaeology'},
#     {'id': 'https://opencontext.org/search/?proj=112-tel-dor-area-g-report&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=112-tel-dor-area-g-report&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/b028c160-092e-4e2d-9738-a40367ad543b',
#      'label': 'Tel Dor, Area G Report',
#      'count': 65,
#      'slug': '112-tel-dor-area-g-report'},
#     {'id': 'https://opencontext.org/search/?proj=14-bade-museum&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=14-bade-museum&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/B4345F6A-F926-4062-144E-3FBC175CC7B6',
#      'label': 'Bade Museum',
#      'count': 46,
#      'slug': '14-bade-museum'},
#     {'id': 'https://opencontext.org/search/?proj=22-kenan-tepe&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=22-kenan-tepe&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/3DE4CD9C-259E-4C14-9B03-8B10454BA66E',
#      'label': 'Kenan Tepe',
#      'count': 15,
#      'slug': '22-kenan-tepe'},
#     {'id': 'https://opencontext.org/search/?proj=93-biometry-of-iron-age-ii-and-hellenistic-period-dog-bur&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=93-biometry-of-iron-age-ii-and-hellenistic-period-dog-bur&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/646b7034-07b7-4971-8d89-ebe37dda4cd2',
#      'label': "Biometry of Iron Age II and Hellenistic Period Dog 'Burials' from Tell Gezer and Other Sites",
#      'count': 15,
#      'slug': '93-biometry-of-iron-age-ii-and-hellenistic-period-dog-bur'},
#     {'id': 'https://opencontext.org/search/?proj=1-domuztepe-excavations&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=1-domuztepe-excavations&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/3',
#      'label': 'Domuztepe Excavations',
#      'count': 14,
#      'slug': '1-domuztepe-excavations'},
#     {'id': 'https://opencontext.org/search/?proj=52-digital-index-of-north-american-archaeology-dinaa&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=52-digital-index-of-north-american-archaeology-dinaa&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/416A274C-CF88-4471-3E31-93DB825E9E4A',
#      'label': 'Digital Index of North American Archaeology (DINAA)',
#      'count': 7,
#      'slug': '52-digital-index-of-north-american-archaeology-dinaa'},
#     {'id': 'https://opencontext.org/search/?proj=91-historic-fort-snelling&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=91-historic-fort-snelling&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/fab0532a-2953-4f13-aa97-8a9d7e992dbe',
#      'label': 'Historic Fort Snelling',
#      'count': 6,
#      'slug': '91-historic-fort-snelling'},
#     {'id': 'https://opencontext.org/search/?proj=99-idalion&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=99-idalion&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/df8e4efd-e06b-4b0b-a056-08b6fd199536',
#      'label': 'Idalion',
#      'count': 6,
#      'slug': '99-idalion'},
#     {'id': 'https://opencontext.org/search/?proj=39-ceramics-trade-provenience-and-geology-cyprus-in-the&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=39-ceramics-trade-provenience-and-geology-cyprus-in-the&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/ABABD13C-A69F-499E-CA7F-5118F3684E4D',
#      'label': 'Ceramics, Trade, Provenience and Geology: Cyprus in the Late Bronze Age',
#      'count': 5,
#      'slug': '39-ceramics-trade-provenience-and-geology-cyprus-in-the'},
#     {'id': 'https://opencontext.org/search/?proj=109-differentiating-local-from-nonlocal-ceramic-production&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=109-differentiating-local-from-nonlocal-ceramic-production&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/cbd24bbb-c6fc-44ed-bd67-6f844f120ad5',
#      'label': 'Differentiating local from nonlocal ceramic production at Iron Age Sardis using NAA',
#      'count': 3,
#      'slug': '109-differentiating-local-from-nonlocal-ceramic-production'},
#     {'id': 'https://opencontext.org/search/?proj=100-paleoindian-database-of-the-americas-pidba&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=100-paleoindian-database-of-the-americas-pidba&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/d75ef68a-0e23-458c-976d-286d83c13013',
#      'label': 'Paleoindian Database of the Americas (PIDBA)',
#      'count': 1,
#      'slug': '100-paleoindian-database-of-the-americas-pidba'},
#     {'id': 'https://opencontext.org/search/?proj=103-architecture-and-urbanism-at-seyitomer-hoyuk-turkey&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=103-architecture-and-urbanism-at-seyitomer-hoyuk-turkey&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/347286db-b6c6-4fd2-b3bd-b50316b0cb9f',
#      'label': 'Architecture and Urbanism at Seyitömer Höyük, Turkey',
#      'count': 1,
#      'slug': '103-architecture-and-urbanism-at-seyitomer-hoyuk-turkey'},
#     {'id': 'https://opencontext.org/search/?proj=20-dhiban-excavation-and-development-project&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=20-dhiban-excavation-and-development-project&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/01D080DF-2F6B-4F59-BCF0-87543AC89574',
#      'label': 'Dhiban Excavation and Development Project',
#      'count': 1,
#      'slug': '20-dhiban-excavation-and-development-project'},
#     {'id': 'https://opencontext.org/search/?proj=21-rough-cilicia&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=21-rough-cilicia&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/295B5BF4-0F44-4698-80CD-7A39CB6F133D',
#      'label': 'Rough Cilicia',
#      'count': 1,
#      'slug': '21-rough-cilicia'},
#     {'id': 'https://opencontext.org/search/?proj=26-zooarchaeology-of-karain-cave-b&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=26-zooarchaeology-of-karain-cave-b&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/731B0670-CE2A-414A-8EF6-9C050A1C60F5',
#      'label': 'Zooarchaeology of Karain Cave B',
#      'count': 1,
#      'slug': '26-zooarchaeology-of-karain-cave-b'},
#     {'id': 'https://opencontext.org/search/?proj=31-barcin-hoyuk-zooarchaeology&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=31-barcin-hoyuk-zooarchaeology&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/74749949-4FD4-4C3E-C830-5AA75703E08E',
#      'label': 'Barçın Höyük Zooarchaeology',
#      'count': 1,
#      'slug': '31-barcin-hoyuk-zooarchaeology'},
#     {'id': 'https://opencontext.org/search/?proj=36-ilipinar-zooarchaeology&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=36-ilipinar-zooarchaeology&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/D297CD29-50CA-4B2C-4A07-498ADF3AF487',
#      'label': 'Ilıpınar Zooarchaeology',
#      'count': 1,
#      'slug': '36-ilipinar-zooarchaeology'},
#     {'id': 'https://opencontext.org/search/?proj=9-iraq-heritage-program&q=roman',
#      'json': 'https://opencontext.org/search/.json?proj=9-iraq-heritage-program&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/projects/GHF1PRJ0000000025',
#      'label': 'Iraq Heritage Program',
#      'count': 1,
#      'slug': '9-iraq-heritage-program'}]},
#   {'id': '#facet-prop-ld',
#    'rdfs:isDefinedBy': 'oc-api:facet-prop-ld',
#    'label': 'Descriptions (Common Standards)',
#    'data-type': 'id',
#    'type': 'oc-api:facet-prop',
#    'oc-api:has-id-options': [{'id': 'https://opencontext.org/search/?prop=dc-terms-temporal&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=dc-terms-temporal&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/dc/terms/temporal',
#      'label': 'Temporal Coverage',
#      'count': 63787,
#      'slug': 'dc-terms-temporal'},
#     {'id': 'https://opencontext.org/search/?prop=cidoc-crm-p2-has-type&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=cidoc-crm-p2-has-type&q=roman',
#      'rdfs:isDefinedBy': 'http://erlangen-crm.org/current/P2_has_type',
#      'label': 'Has type',
#      'count': 7824,
#      'slug': 'cidoc-crm-p2-has-type'},
#     {'id': 'https://opencontext.org/search/?prop=skos-related&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=skos-related&q=roman',
#      'rdfs:isDefinedBy': 'http://www.w3.org/2004/02/skos/core#related',
#      'label': 'Related',
#      'count': 4410,
#      'slug': 'skos-related'},
#     {'id': 'https://opencontext.org/search/?prop=rel--cidoc-crm-p2-has-type&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=rel--cidoc-crm-p2-has-type&q=roman',
#      'rdfs:isDefinedBy': 'http://erlangen-crm.org/current/P2_has_type',
#      'label': 'Has type',
#      'count': 3550,
#      'slug': 'rel--cidoc-crm-p2-has-type'},
#     {'id': 'https://opencontext.org/search/?prop=cidoc-crm-p45-consists-of&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=cidoc-crm-p45-consists-of&q=roman',
#      'rdfs:isDefinedBy': 'http://erlangen-crm.org/current/P45_consists_of',
#      'label': 'Consists of',
#      'count': 2933,
#      'slug': 'cidoc-crm-p45-consists-of'},
#     {'id': 'https://opencontext.org/search/?prop=rel--cidoc-crm-p45-consists-of&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=rel--cidoc-crm-p45-consists-of&q=roman',
#      'rdfs:isDefinedBy': 'http://erlangen-crm.org/current/P45_consists_of',
#      'label': 'Consists of',
#      'count': 1455,
#      'slug': 'rel--cidoc-crm-p45-consists-of'},
#     {'id': 'https://opencontext.org/search/?prop=oc-zoo-has-anat-id&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=oc-zoo-has-anat-id&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/vocabularies/open-context-zooarch/has-anat-id',
#      'label': 'Has anatomical identification',
#      'count': 988,
#      'slug': 'oc-zoo-has-anat-id'},
#     {'id': 'https://opencontext.org/search/?prop=biol-term-hastaxonomy&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=biol-term-hastaxonomy&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/NET/biol/ns#term_hasTaxonomy',
#      'label': 'Has Biological Taxonomy',
#      'count': 964,
#      'slug': 'biol-term-hastaxonomy'},
#     {'id': 'https://opencontext.org/search/?prop=oc-zoo-anatomical-meas&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=oc-zoo-anatomical-meas&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/vocabularies/open-context-zooarch/anatomical-meas',
#      'label': 'Anatomical measurement',
#      'count': 542,
#      'slug': 'oc-zoo-anatomical-meas'},
#     {'id': 'https://opencontext.org/search/?prop=dc-terms-references&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=dc-terms-references&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/dc/terms/references',
#      'label': 'References',
#      'count': 527,
#      'slug': 'dc-terms-references'},
#     {'id': 'https://opencontext.org/search/?prop=oc-zoo-has-fusion-char&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=oc-zoo-has-fusion-char&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/vocabularies/open-context-zooarch/has-fusion-char',
#      'label': 'Has fusion character',
#      'count': 521,
#      'slug': 'oc-zoo-has-fusion-char'},
#     {'id': 'https://opencontext.org/search/?prop=dc-terms-ispartof&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=dc-terms-ispartof&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/dc/terms/isPartOf',
#      'label': 'Is Part Of',
#      'count': 491,
#      'slug': 'dc-terms-ispartof'},
#     {'id': 'https://opencontext.org/search/?prop=skos-closematch&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=skos-closematch&q=roman',
#      'rdfs:isDefinedBy': 'http://www.w3.org/2004/02/skos/core#closeMatch',
#      'label': 'Close Match',
#      'count': 429,
#      'slug': 'skos-closematch'},
#     {'id': 'https://opencontext.org/search/?prop=rel--gawd-origin&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=rel--gawd-origin&q=roman',
#      'rdfs:isDefinedBy': 'http://gawd.atlantides.org/terms/origin',
#      'label': 'Origin place',
#      'count': 137,
#      'slug': 'rel--gawd-origin'},
#     {'id': 'https://opencontext.org/search/?prop=rel--dc-terms-subject&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=rel--dc-terms-subject&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/dc/terms/subject',
#      'label': 'Subject',
#      'count': 125,
#      'slug': 'rel--dc-terms-subject'},
#     {'id': 'https://opencontext.org/search/?prop=gawd-origin&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=gawd-origin&q=roman',
#      'rdfs:isDefinedBy': 'http://gawd.atlantides.org/terms/origin',
#      'label': 'Origin place',
#      'count': 70,
#      'slug': 'gawd-origin'},
#     {'id': 'https://opencontext.org/search/?prop=dc-terms-subject&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=dc-terms-subject&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/dc/terms/subject',
#      'label': 'Subject',
#      'count': 50,
#      'slug': 'dc-terms-subject'},
#     {'id': 'https://opencontext.org/search/?prop=dc-terms-isreferencedby&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=dc-terms-isreferencedby&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/dc/terms/isReferencedBy',
#      'label': 'Is Referenced By',
#      'count': 18,
#      'slug': 'dc-terms-isreferencedby'},
#     {'id': 'https://opencontext.org/search/?prop=dc-terms-haspart&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=dc-terms-haspart&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/dc/terms/hasPart',
#      'label': 'Has Part',
#      'count': 17,
#      'slug': 'dc-terms-haspart'},
#     {'id': 'https://opencontext.org/search/?prop=bibo-status&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=bibo-status&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/ontology/bibo/status',
#      'label': 'Status',
#      'count': 16,
#      'slug': 'bibo-status'},
#     {'id': 'https://opencontext.org/search/?prop=dc-terms-spatial&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=dc-terms-spatial&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/dc/terms/spatial',
#      'label': 'Spatial',
#      'count': 14,
#      'slug': 'dc-terms-spatial'},
#     {'id': 'https://opencontext.org/search/?prop=dc-terms-coverage&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=dc-terms-coverage&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/dc/terms/coverage',
#      'label': 'Coverage',
#      'count': 11,
#      'slug': 'dc-terms-coverage'},
#     {'id': 'https://opencontext.org/search/?prop=oc-zoo-has-phys-sex-det&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=oc-zoo-has-phys-sex-det&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/vocabularies/open-context-zooarch/has-phys-sex-det',
#      'label': 'Has physiological sex determination',
#      'count': 8,
#      'slug': 'oc-zoo-has-phys-sex-det'},
#     {'id': 'https://opencontext.org/search/?prop=dinaa-00001&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=dinaa-00001&q=roman',
#      'rdfs:isDefinedBy': 'http://opencontext.org/vocabularies/dinaa/00001',
#      'label': 'Has period',
#      'count': 6,
#      'slug': 'dinaa-00001'},
#     {'id': 'https://opencontext.org/search/?prop=rel--dc-terms-references&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=rel--dc-terms-references&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/dc/terms/references',
#      'label': 'References',
#      'count': 4,
#      'slug': 'rel--dc-terms-references'}],
#    'oc-api:has-text-options': [{'id': 'https://opencontext.org/search/?prop=rel--skos-altlabel&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=rel--skos-altlabel&q=roman',
#      'rdfs:isDefinedBy': 'http://www.w3.org/2004/02/skos/core#altLabel',
#      'label': 'Alternative label',
#      'count': 133,
#      'slug': 'rel--skos-altlabel'},
#     {'id': 'https://opencontext.org/search/?prop=skos-altlabel&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=skos-altlabel&q=roman',
#      'rdfs:isDefinedBy': 'http://www.w3.org/2004/02/skos/core#altLabel',
#      'label': 'Alternative label',
#      'count': 6,
#      'slug': 'skos-altlabel'},
#     {'id': 'https://opencontext.org/search/?prop=dc-terms-identifier&q=roman',
#      'json': 'https://opencontext.org/search/.json?prop=dc-terms-identifier&q=roman',
#      'rdfs:isDefinedBy': 'http://purl.org/dc/terms/identifier',
#      'label': 'Identifier',
#      'count': 3,
#      'slug': 'dc-terms-identifier'}]},
#   {'id': '#related-media',
#    'label': 'Has Related Media',
#    'oc-api:has-rel-media-options': [{'id': 'https://opencontext.org/search/?images=1&q=roman',
#      'json': 'https://opencontext.org/search/.json?images=1&q=roman',
#      'label': 'Linked with images',
#      'count': 3348},
#     {'id': 'https://opencontext.org/search/?other-media=1&q=roman',
#      'json': 'https://opencontext.org/search/.json?other-media=1&q=roman',
#      'label': 'Linked with media (non-image)',
#      'count': 108},
#     {'id': 'https://opencontext.org/search/?documents=1&q=roman',
#      'json': 'https://opencontext.org/search/.json?documents=1&q=roman',
#      'label': 'Linked with documents',
#      'count': 19}]}],
#  'type': 'FeatureCollection',
#  'features': [{'id': 'https://opencontext.org/search/?disc-geotile=021333&q=roman',
#    'json': 'https://opencontext.org/search/.json?disc-geotile=021333&q=roman',
#    'count': 6,
#    'type': 'Feature',
#    'category': 'oc-api:geo-facet',
#    'when': {'id': '#event-021333',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-336999',
#     'stop': '1950'},
#    'geometry': {'id': '#geo-disc-tile-geom-021333',
#     'type': 'Polygon',
#     'coordinates': [[[-95.625, 40.979898069620155],
#       [-90.0, 40.979898069620155],
#       [-90.0, 45.089035564831015],
#       [-95.625, 45.089035564831015],
#       [-95.625, 40.979898069620155]]]},
#    'properties': {'id': '#geo-disc-tile-021333',
#     'href': 'https://opencontext.org/search/?disc-geotile=021333&q=roman',
#     'label': 'Discovery region (1)',
#     'feature-type': 'discovery region (facet)',
#     'count': 6,
#     'early bce/ce': -337000,
#     'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?disc-geotile=023131&q=roman',
#    'json': 'https://opencontext.org/search/.json?disc-geotile=023131&q=roman',
#    'count': 3,
#    'type': 'Feature',
#    'category': 'oc-api:geo-facet',
#    'when': {'id': '#event-023131',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-336999',
#     'stop': '1950'},
#    'geometry': {'id': '#geo-disc-tile-geom-023131',
#     'type': 'Polygon',
#     'coordinates': [[[-95.625, 27.059125784374068],
#       [-90.0, 27.059125784374068],
#       [-90.0, 31.952162238024975],
#       [-95.625, 31.952162238024975],
#       [-95.625, 27.059125784374068]]]},
#    'properties': {'id': '#geo-disc-tile-023131',
#     'href': 'https://opencontext.org/search/?disc-geotile=023131&q=roman',
#     'label': 'Discovery region (2)',
#     'feature-type': 'discovery region (facet)',
#     'count': 3,
#     'early bce/ce': -337000,
#     'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?disc-geotile=023301&q=roman',
#    'json': 'https://opencontext.org/search/.json?disc-geotile=023301&q=roman',
#    'count': 1,
#    'type': 'Feature',
#    'category': 'oc-api:geo-facet',
#    'when': {'id': '#event-023301',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-336999',
#     'stop': '1950'},
#    'geometry': {'id': '#geo-disc-tile-geom-023301',
#     'type': 'Polygon',
#     'coordinates': [[[-106.875, 16.636191878397664],
#       [-101.25, 16.636191878397664],
#       [-101.25, 21.943045533438166],
#       [-106.875, 21.943045533438166],
#       [-106.875, 16.636191878397664]]]},
#    'properties': {'id': '#geo-disc-tile-023301',
#     'href': 'https://opencontext.org/search/?disc-geotile=023301&q=roman',
#     'label': 'Discovery region (3)',
#     'feature-type': 'discovery region (facet)',
#     'count': 1,
#     'early bce/ce': -337000,
#     'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?disc-geotile=030222&q=roman',
#    'json': 'https://opencontext.org/search/.json?disc-geotile=030222&q=roman',
#    'count': 1,
#    'type': 'Feature',
#    'category': 'oc-api:geo-facet',
#    'when': {'id': '#event-030222',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-336999',
#     'stop': '1950'},
#    'geometry': {'id': '#geo-disc-tile-geom-030222',
#     'type': 'Polygon',
#     'coordinates': [[[-90.0, 40.979898069620155],
#       [-84.375, 40.979898069620155],
#       [-84.375, 45.089035564831015],
#       [-90.0, 45.089035564831015],
#       [-90.0, 40.979898069620155]]]},
#    'properties': {'id': '#geo-disc-tile-030222',
#     'href': 'https://opencontext.org/search/?disc-geotile=030222&q=roman',
#     'label': 'Discovery region (4)',
#     'feature-type': 'discovery region (facet)',
#     'count': 1,
#     'early bce/ce': -337000,
#     'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?disc-geotile=032000&q=roman',
#    'json': 'https://opencontext.org/search/.json?disc-geotile=032000&q=roman',
#    'count': 1,
#    'type': 'Feature',
#    'category': 'oc-api:geo-facet',
#    'when': {'id': '#event-032000',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-336999',
#     'stop': '1950'},
#    'geometry': {'id': '#geo-disc-tile-geom-032000',
#     'type': 'Polygon',
#     'coordinates': [[[-90.0, 36.5978891330702],
#       [-84.375, 36.5978891330702],
#       [-84.375, 40.979898069620155],
#       [-90.0, 40.979898069620155],
#       [-90.0, 36.5978891330702]]]},
#    'properties': {'id': '#geo-disc-tile-032000',
#     'href': 'https://opencontext.org/search/?disc-geotile=032000&q=roman',
#     'label': 'Discovery region (5)',
#     'feature-type': 'discovery region (facet)',
#     'count': 1,
#     'early bce/ce': -337000,
#     'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?disc-geotile=032021&q=roman',
#    'json': 'https://opencontext.org/search/.json?disc-geotile=032021&q=roman',
#    'count': 2,
#    'type': 'Feature',
#    'category': 'oc-api:geo-facet',
#    'when': {'id': '#event-032021',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-336999',
#     'stop': '1950'},
#    'geometry': {'id': '#geo-disc-tile-geom-032021',
#     'type': 'Polygon',
#     'coordinates': [[[-84.375, 27.059125784374068],
#       [-78.75000000000001, 27.059125784374068],
#       [-78.75000000000001, 31.952162238024975],
#       [-84.375, 31.952162238024975],
#       [-84.375, 27.059125784374068]]]},
#    'properties': {'id': '#geo-disc-tile-032021',
#     'href': 'https://opencontext.org/search/?disc-geotile=032021&q=roman',
#     'label': 'Discovery region (6)',
#     'feature-type': 'discovery region (facet)',
#     'count': 2,
#     'early bce/ce': -337000,
#     'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?disc-geotile=033111&q=roman',
#    'json': 'https://opencontext.org/search/.json?disc-geotile=033111&q=roman',
#    'count': 28,
#    'type': 'Feature',
#    'category': 'oc-api:geo-facet',
#    'when': {'id': '#event-033111',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-336999',
#     'stop': '1950'},
#    'geometry': {'id': '#geo-disc-tile-geom-033111',
#     'type': 'Polygon',
#     'coordinates': [[[-5.625000000000013, 36.5978891330702],
#       [0.0, 36.5978891330702],
#       [0.0, 40.979898069620155],
#       [-5.625000000000013, 40.979898069620155],
#       [-5.625000000000013, 36.5978891330702]]]},
#    'properties': {'id': '#geo-disc-tile-033111',
#     'href': 'https://opencontext.org/search/?disc-geotile=033111&q=roman',
#     'label': 'Discovery region (7)',
#     'feature-type': 'discovery region (facet)',
#     'count': 28,
#     'early bce/ce': -337000,
#     'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?disc-geotile=120201&q=roman',
#    'json': 'https://opencontext.org/search/.json?disc-geotile=120201&q=roman',
#    'count': 127,
#    'type': 'Feature',
#    'category': 'oc-api:geo-facet',
#    'when': {'id': '#event-120201',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-336999',
#     'stop': '1950'},
#    'geometry': {'id': '#geo-disc-tile-geom-120201',
#     'type': 'Polygon',
#     'coordinates': [[[5.625000000000013, 52.482780222078226],
#       [11.249999999999993, 52.482780222078226],
#       [11.249999999999993, 55.7765730186677],
#       [5.625000000000013, 55.7765730186677],
#       [5.625000000000013, 52.482780222078226]]]},
#    'properties': {'id': '#geo-disc-tile-120201',
#     'href': 'https://opencontext.org/search/?disc-geotile=120201&q=roman',
#     'label': 'Discovery region (8)',
#     'feature-type': 'discovery region (facet)',
#     'count': 127,
#     'early bce/ce': -337000,
#     'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?disc-geotile=120203&q=roman',
#    'json': 'https://opencontext.org/search/.json?disc-geotile=120203&q=roman',
#    'count': 263,
#    'type': 'Feature',
#    'category': 'oc-api:geo-facet',
#    'when': {'id': '#event-120203',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-336999',
#     'stop': '1950'},
#    'geometry': {'id': '#geo-disc-tile-geom-120203',
#     'type': 'Polygon',
#     'coordinates': [[[5.625000000000013, 48.922499263758255],
#       [11.249999999999993, 48.922499263758255],
#       [11.249999999999993, 52.482780222078226],
#       [5.625000000000013, 52.482780222078226],
#       [5.625000000000013, 48.922499263758255]]]},
#    'properties': {'id': '#geo-disc-tile-120203',
#     'href': 'https://opencontext.org/search/?disc-geotile=120203&q=roman',
#     'label': 'Discovery region (9)',
#     'feature-type': 'discovery region (facet)',
#     'count': 263,
#     'early bce/ce': -337000,
#     'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?disc-geotile=120210&q=roman',
#    'json': 'https://opencontext.org/search/.json?disc-geotile=120210&q=roman',
#    'count': 29,
#    'type': 'Feature',
#    'category': 'oc-api:geo-facet',
#    'when': {'id': '#event-120210',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-336999',
#     'stop': '1950'},
#    'geometry': {'id': '#geo-disc-tile-geom-120210',
#     'type': 'Polygon',
#     'coordinates': [[[11.249999999999993, 52.482780222078226],
#       [16.875000000000007, 52.482780222078226],
#       [16.875000000000007, 55.7765730186677],
#       [11.249999999999993, 55.7765730186677],
#       [11.249999999999993, 52.482780222078226]]]},
#    'properties': {'id': '#geo-disc-tile-120210',
#     'href': 'https://opencontext.org/search/?disc-geotile=120210&q=roman',
#     'label': 'Discovery region (10)',
#     'feature-type': 'discovery region (facet)',
#     'count': 29,
#     'early bce/ce': -337000,
#     'late bce/ce': 1950}},
#   {'id': 'https://opencontext.org/search/?disc-geotile=120211&q=roman',
#    'json': 'https://opencontext.org/search/.json?disc-geotile=120211&q=roman',
#    'count': 10,
#    'type': 'Feature',
#    'category': 'oc-api:geo-facet',
#    'when': {'id': '#event-120211',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-336999',
#     'stop': '1950'},
#    'geometry': {'id': '#geo-disc-tile-geom-120211',
#     'type': 'Polygon',
# ...
#     'project href': 'https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9',
#     'context label': 'Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Roman Pavement/Removal 15',
#     'context href': 'https://opencontext.org/subjects/c89534ea-27ef-4989-9330-188925c983b8',
#     'early bce/ce': False,
#     'late bce/ce': False,
#     'item category': 'Image',
#     'snippet': 'Drawing d-e-020 from Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/<em>Roman</em> Pavement/Removal',
#     'thumbnail': 'https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-e-020.jpg',
#     'published': '2017-12-23T01:01:33Z',
#     'updated': '2018-03-23T01:04:19Z'}},
#   {'id': '#record-10-of-77460',
#    'label': 'Drawing d-e-021',
#    'rdfs:isDefinedBy': 'http://opencontext.org/media/14851d29-eb3f-431e-84cc-d1d90fc165eb',
#    'type': 'Feature',
#    'category': 'oc-api:geo-record',
#    'geometry': {'id': '#geo-rec-geom-10-of-77460',
#     'type': 'Point',
#     'coordinates': [31.13804786067644, 29.97526634987221]},
#    'properties': {'id': '#rec-10-of-77460',
#     'feature-type': 'item record',
#     'uri': 'http://opencontext.org/media/14851d29-eb3f-431e-84cc-d1d90fc165eb',
#     'href': 'https://opencontext.org/media/14851d29-eb3f-431e-84cc-d1d90fc165eb',
#     'citation uri': False,
#     'label': 'Drawing d-e-021',
#     'project label': 'ARCE Sphinx Project 1979-1983 Archive',
#     'project href': 'https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9',
#     'context label': 'Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Roman Pavement/Removal 15',
#     'context href': 'https://opencontext.org/subjects/c89534ea-27ef-4989-9330-188925c983b8',
#     'early bce/ce': False,
#     'late bce/ce': False,
#     'item category': 'Image',
#     'snippet': 'Drawing d-e-021 from Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/<em>Roman</em> Pavement/Removal',
#     'thumbnail': 'https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-e-021.jpg',
#     'published': '2017-12-23T01:01:34Z',
#     'updated': '2018-03-23T01:02:54Z'}},
#   {'id': '#record-11-of-77460',
#    'label': 'Drawing d-gen-011',
#    'rdfs:isDefinedBy': 'http://opencontext.org/media/e4c24bfd-6199-4d66-9af2-392ee138a247',
#    'type': 'Feature',
#    'category': 'oc-api:geo-record',
#    'geometry': {'id': '#geo-rec-geom-11-of-77460',
#     'type': 'Point',
#     'coordinates': [31.13832000374021, 29.975190517527544]},
#    'properties': {'id': '#rec-11-of-77460',
#     'feature-type': 'item record',
#     'uri': 'http://opencontext.org/media/e4c24bfd-6199-4d66-9af2-392ee138a247',
#     'href': 'https://opencontext.org/media/e4c24bfd-6199-4d66-9af2-392ee138a247',
#     'citation uri': False,
#     'label': 'Drawing d-gen-011',
#     'project label': 'ARCE Sphinx Project 1979-1983 Archive',
#     'project href': 'https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9',
#     'context label': 'Egypt/Giza/Terrace 1/Sphinx Temple',
#     'context href': 'https://opencontext.org/subjects/1a934b66-8bd6-476e-94c1-fdb51c456aa9',
#     'early bce/ce': False,
#     'late bce/ce': False,
#     'item category': 'Image',
#     'snippet': ' including: Sphinx Temple NW Corner, Sphinx North Forepaw, Pavement, <em>Roman</em> Stairs, North Ledge, Amenhotep II',
#     'thumbnail': 'https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings-B/d-gen-011.jpg',
#     'published': '2017-12-23T01:02:55Z',
#     'updated': '2018-03-23T01:20:43Z'}},
#   {'id': '#record-12-of-77460',
#    'label': 'Drawing d-e-024',
#    'rdfs:isDefinedBy': 'http://opencontext.org/media/af4246af-16a1-4770-b00a-f16f774dacf9',
#    'type': 'Feature',
#    'category': 'oc-api:geo-record',
#    'geometry': {'id': '#geo-rec-geom-12-of-77460',
#     'type': 'Point',
#     'coordinates': [31.137937830616877, 29.97526657483614]},
#    'properties': {'id': '#rec-12-of-77460',
#     'feature-type': 'item record',
#     'uri': 'http://opencontext.org/media/af4246af-16a1-4770-b00a-f16f774dacf9',
#     'href': 'https://opencontext.org/media/af4246af-16a1-4770-b00a-f16f774dacf9',
#     'citation uri': False,
#     'label': 'Drawing d-e-024',
#     'project label': 'ARCE Sphinx Project 1979-1983 Archive',
#     'project href': 'https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9',
#     'context label': 'Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Removal 14',
#     'context href': 'https://opencontext.org/subjects/37cbe2aa-1877-4eba-b3a5-45c43d13abc9',
#     'early bce/ce': False,
#     'late bce/ce': False,
#     'item category': 'Image',
#     'snippet': ' amount of deposits immediately south of the <em>Roman</em> Stairs, between the stairs and the Sound and Light box',
#     'thumbnail': 'https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-e-024.jpg',
#     'published': '2017-12-23T01:01:36Z',
#     'updated': '2018-03-23T01:02:37Z'}},
#   {'id': '#record-13-of-77460',
#    'label': '2672',
#    'rdfs:isDefinedBy': 'http://opencontext.org/media/99496876-67e8-408f-8da6-212f515ef67f',
#    'type': 'Feature',
#    'category': 'oc-api:geo-record',
#    'geometry': {'id': '#geo-rec-geom-13-of-77460',
#     'type': 'Point',
#     'coordinates': [12.719486146888293, 41.88774442934475]},
#    'when': {'id': '#event-rec-when-13-of-77460',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-0674',
#     'stop': '0001'},
#    'properties': {'id': '#rec-13-of-77460',
#     'feature-type': 'item record',
#     'uri': 'http://opencontext.org/media/99496876-67e8-408f-8da6-212f515ef67f',
#     'href': 'https://opencontext.org/media/99496876-67e8-408f-8da6-212f515ef67f',
#     'citation uri': False,
#     'label': '2672',
#     'project label': 'The Gabii Project',
#     'project href': 'https://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd',
#     'context label': 'Italy/Gabii/Area B/Unit 1242',
#     'context href': 'https://opencontext.org/subjects/4d680e71-b622-42eb-9577-bd0eec2a8251',
#     'early bce/ce': -675.0,
#     'late bce/ce': 1.0,
#     'item category': 'Image',
#     'snippet': ' Priority  Medium  \n File Attachment Filename 2672.pdf \n \n<em>Roman</em> Republican\nhttp://n2t.net/ark:/99152',
#     'thumbnail': 'https://opencontext.org/static/oc/images/icons/3d-noun-37529.png',
#     'published': '2017-06-04T23:26:17Z',
#     'updated': '2018-01-31T08:20:27Z'}},
#   {'id': '#record-14-of-77460',
#    'label': '2770',
#    'rdfs:isDefinedBy': 'http://opencontext.org/media/9d2ca9a6-127a-475f-8698-6acaf47f3967',
#    'type': 'Feature',
#    'category': 'oc-api:geo-record',
#    'geometry': {'id': '#geo-rec-geom-14-of-77460',
#     'type': 'Point',
#     'coordinates': [12.719685707676424, 41.88771672158477]},
#    'when': {'id': '#event-rec-when-14-of-77460',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-0899',
#     'stop': '0200'},
#    'properties': {'id': '#rec-14-of-77460',
#     'feature-type': 'item record',
#     'uri': 'http://opencontext.org/media/9d2ca9a6-127a-475f-8698-6acaf47f3967',
#     'href': 'https://opencontext.org/media/9d2ca9a6-127a-475f-8698-6acaf47f3967',
#     'citation uri': False,
#     'label': '2770',
#     'project label': 'The Gabii Project',
#     'project href': 'https://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd',
#     'context label': 'Italy/Gabii/Area B/Unit 1386',
#     'context href': 'https://opencontext.org/subjects/321b8a74-9782-450b-93e2-82d963cb2f8f',
#     'early bce/ce': -900.0,
#     'late bce/ce': 200.0,
#     'item category': 'Image',
#     'snippet': '  Medium  \n File Attachment Filename 2770.pdf \n \n<em>Roman</em> Republican\nhttp://n2t.net/ark:/99152/p0qhb66mvjk',
#     'thumbnail': 'https://opencontext.org/static/oc/images/icons/3d-noun-37529.png',
#     'published': '2017-06-04T23:32:24Z',
#     'updated': '2018-01-31T08:18:05Z'}},
#   {'id': '#record-15-of-77460',
#    'label': 'Drawing d-e-042',
#    'rdfs:isDefinedBy': 'http://opencontext.org/media/f9d43eb2-12bd-4f8a-9f78-4ecba5406e07',
#    'type': 'Feature',
#    'category': 'oc-api:geo-record',
#    'geometry': {'id': '#geo-rec-geom-15-of-77460',
#     'type': 'Point',
#     'coordinates': [31.137937830616877, 29.97526657483614]},
#    'properties': {'id': '#rec-15-of-77460',
#     'feature-type': 'item record',
#     'uri': 'http://opencontext.org/media/f9d43eb2-12bd-4f8a-9f78-4ecba5406e07',
#     'href': 'https://opencontext.org/media/f9d43eb2-12bd-4f8a-9f78-4ecba5406e07',
#     'citation uri': False,
#     'label': 'Drawing d-e-042',
#     'project label': 'ARCE Sphinx Project 1979-1983 Archive',
#     'project href': 'https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9',
#     'context label': 'Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East',
#     'context href': 'https://opencontext.org/subjects/5714b49e-a383-4738-9235-29841bfaaba0',
#     'early bce/ce': False,
#     'late bce/ce': False,
#     'item category': 'Image',
#     'snippet': '  \n Resource Type  Drawings  \n Keywords  Chapel  Forepaws  Masonry  <em>Roman</em> Pavement  \n Scale 1:50 \n \n Creator',
#     'thumbnail': 'https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings-B/d-e-042.jpg',
#     'published': '2017-12-23T01:01:46Z',
#     'updated': '2018-03-23T01:06:48Z'}},
#   {'id': '#record-16-of-77460',
#    'label': 'Drawing d-e-066',
#    'rdfs:isDefinedBy': 'http://opencontext.org/media/8b650f2e-2196-45d1-aa17-535943293d23',
#    'type': 'Feature',
#    'category': 'oc-api:geo-record',
#    'geometry': {'id': '#geo-rec-geom-16-of-77460',
#     'type': 'Point',
#     'coordinates': [31.137937830616877, 29.97526657483614]},
#    'properties': {'id': '#rec-16-of-77460',
#     'feature-type': 'item record',
#     'uri': 'http://opencontext.org/media/8b650f2e-2196-45d1-aa17-535943293d23',
#     'href': 'https://opencontext.org/media/8b650f2e-2196-45d1-aa17-535943293d23',
#     'citation uri': 'http://n2t.net/ark:/28722/k2nv9pv9c',
#     'label': 'Drawing d-e-066',
#     'project label': 'ARCE Sphinx Project 1979-1983 Archive',
#     'project href': 'https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9',
#     'context label': 'Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Removal 14',
#     'context href': 'https://opencontext.org/subjects/37cbe2aa-1877-4eba-b3a5-45c43d13abc9',
#     'early bce/ce': False,
#     'late bce/ce': False,
#     'item category': 'Image',
#     'snippet': ') R14 \n \n Description R14 was the removal of a small amount of deposits immediately south of the <em>Roman</em>',
#     'thumbnail': 'https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings-B/d-e-066.jpg',
#     'published': '2017-12-23T01:02:02Z',
#     'updated': '2018-03-23T01:04:33Z'}},
#   {'id': '#record-17-of-77460',
#    'label': 'Drawing d-e-064',
#    'rdfs:isDefinedBy': 'http://opencontext.org/media/0bc963d4-40da-406c-b395-696ea87618be',
#    'type': 'Feature',
#    'category': 'oc-api:geo-record',
#    'geometry': {'id': '#geo-rec-geom-17-of-77460',
#     'type': 'Point',
#     'coordinates': [31.137937830616877, 29.97526657483614]},
#    'properties': {'id': '#rec-17-of-77460',
#     'feature-type': 'item record',
#     'uri': 'http://opencontext.org/media/0bc963d4-40da-406c-b395-696ea87618be',
#     'href': 'https://opencontext.org/media/0bc963d4-40da-406c-b395-696ea87618be',
#     'citation uri': 'http://n2t.net/ark:/28722/k2sn0dp45',
#     'label': 'Drawing d-e-064',
#     'project label': 'ARCE Sphinx Project 1979-1983 Archive',
#     'project href': 'https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9',
#     'context label': 'Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Removal 14',
#     'context href': 'https://opencontext.org/subjects/37cbe2aa-1877-4eba-b3a5-45c43d13abc9',
#     'early bce/ce': False,
#     'late bce/ce': False,
#     'item category': 'Image',
#     'snippet': ' was the removal of a small amount of deposits immediately south of the <em>Roman</em> Stairs, between the',
#     'thumbnail': 'https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings-B/d-e-064.jpg',
#     'published': '2017-12-23T01:02:01Z',
#     'updated': '2018-03-23T01:02:22Z'}},
#   {'id': '#record-18-of-77460',
#    'label': '2843',
#    'rdfs:isDefinedBy': 'http://opencontext.org/media/9409bf05-af66-4314-b78c-dec7d3a58c77',
#    'type': 'Feature',
#    'category': 'oc-api:geo-record',
#    'geometry': {'id': '#geo-rec-geom-18-of-77460',
#     'type': 'Point',
#     'coordinates': [12.719678174242606, 41.88768863730048]},
#    'properties': {'id': '#rec-18-of-77460',
#     'feature-type': 'item record',
#     'uri': 'http://opencontext.org/media/9409bf05-af66-4314-b78c-dec7d3a58c77',
#     'href': 'https://opencontext.org/media/9409bf05-af66-4314-b78c-dec7d3a58c77',
#     'citation uri': False,
#     'label': '2843',
#     'project label': 'The Gabii Project',
#     'project href': 'https://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd',
#     'context label': 'Italy/Gabii/Area B/Unit 1468',
#     'context href': 'https://opencontext.org/subjects/fadbab7d-868a-4b20-b9b9-b54f5544d156',
#     'early bce/ce': False,
#     'late bce/ce': False,
#     'item category': 'Image',
#     'snippet': ' Attachment Priority  High  \n File Attachment Filename 2843.pdf \n \n<em>Roman</em> Republican\nhttp://n2t.net/ark:/99152',
#     'thumbnail': 'https://opencontext.org/static/oc/images/icons/3d-noun-37529.png',
#     'published': '2017-06-04T23:33:47Z',
#     'updated': '2018-01-31T08:17:31Z'}},
#   {'id': '#record-19-of-77460',
#    'label': '2709',
#    'rdfs:isDefinedBy': 'http://opencontext.org/media/eeee731e-4394-452b-871d-8b82add85ae2',
#    'type': 'Feature',
#    'category': 'oc-api:geo-record',
#    'geometry': {'id': '#geo-rec-geom-19-of-77460',
#     'type': 'Point',
#     'coordinates': [12.719596721093325, 41.88778964097052]},
#    'when': {'id': '#event-rec-when-19-of-77460',
#     'type': 'oc-gen:formation-use-life',
#     'start': '-0399',
#     'stop': '0900'},
#    'properties': {'id': '#rec-19-of-77460',
#     'feature-type': 'item record',
#     'uri': 'http://opencontext.org/media/eeee731e-4394-452b-871d-8b82add85ae2',
#     'href': 'https://opencontext.org/media/eeee731e-4394-452b-871d-8b82add85ae2',
#     'citation uri': False,
#     'label': '2709',
#     'project label': 'The Gabii Project',
#     'project href': 'https://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd',
#     'context label': 'Italy/Gabii/Area B/Unit 1321',
#     'context href': 'https://opencontext.org/subjects/afe93991-1894-42eb-a1d8-93a3d03dfa6c',
#     'early bce/ce': -400.0,
#     'late bce/ce': 900.0,
#     'item category': 'Image',
#     'snippet': '  \n File Attachment Filename 2709.pdf \n \n<em>Roman</em> Republican\nhttp://n2t.net/ark:/99152/p0qhb66mvjk\nTemporal',
#     'thumbnail': 'https://opencontext.org/static/oc/images/icons/3d-noun-37529.png',
#     'published': '2017-06-04T23:31:38Z',
#     'updated': '2018-01-31T08:21:34Z'}},
#   {'id': '#record-20-of-77460',
#    'label': 'Drawing d-se-001',
#    'rdfs:isDefinedBy': 'http://opencontext.org/media/10a6fd7d-e922-407c-91f1-c492b3b1e6ef',
#    'type': 'Feature',
#    'category': 'oc-api:geo-record',
#    'geometry': {'id': '#geo-rec-geom-20-of-77460',
#     'type': 'Point',
#     'coordinates': [31.137930070235992, 29.97510631209676]},
#    'properties': {'id': '#rec-20-of-77460',
#     'feature-type': 'item record',
#     'uri': 'http://opencontext.org/media/10a6fd7d-e922-407c-91f1-c492b3b1e6ef',
#     'href': 'https://opencontext.org/media/10a6fd7d-e922-407c-91f1-c492b3b1e6ef',
#     'citation uri': False,
#     'label': 'Drawing d-se-001',
#     'project label': 'ARCE Sphinx Project 1979-1983 Archive',
#     'project href': 'https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9',
#     'context label': 'Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx Southeast/Feature FSEd3',
#     'context href': 'https://opencontext.org/subjects/3013a0b2-dfc8-419c-a1ee-23ad344e7d4f',
#     'early bce/ce': False,
#     'late bce/ce': False,
#     'item category': 'Image',
#     'snippet': ', south of <em>Roman</em> pavement \n \n Year  \n Resource Type  Drawings  \n Keywords  Bedrock  Depression  Floor',
#     'thumbnail': 'https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-se-001.jpg',
#     'published': '2017-12-23T01:04:03Z',
#     'updated': '2018-03-23T01:05:26Z'}}]}

# %% [markdown]
# 9. To make the JSON data easier to read, we'll add some color and indent some of the text. First we need to bring in the Pygments library.
#
# `import json`
#
# `from pygments import highlight, lexers, formatters`
#
# Then indent the text.
#
# `formatted_data = json.dumps(data, indent=2)`
#
# Then color the text.
#
# `highlighted_data = highlight(formatted_data, lexers.JsonLexer(), formatters.TerminalFormatter())`

# %%
highlighted_data = highlight(formatted_data, lexers.JsonLexer(), formatters.TerminalFormatter())

# %%
formatted_data = json.dumps(data, indent=2)

# %%
import json

from pygments import highlight, lexers, formatters

# %% [markdown]
# 10. Now display the new JSON data.
#
# `print(highlighted_data)`

# %%
print(highlighted_data)
# Out:
# {
#   "@context": [
#     "https://opencontext.org/contexts/search.json",
#     "http://geojson.org/geojson-ld/geojson-context.jsonld"
#   ],
#   "id": "http://opencontext.org/search/.json?q=roman",
#   "label": "Open Context API",
#   "dcmi:modified": "2019-12-04T22:10:19Z",
#   "dcmi:created": "2019-11-06T05:10:54Z",
#   "oai-pmh:earliestDatestamp": "2006-02-28T00:00:00Z",
#   "start": "-336999",
#   "stop": "2015",
#   "dc-terms:temporal": "-336999/2015",
#   "totalResults": 77460,
#   "startIndex": 0,
#   "itemsPerPage": 20,
#   "next": "https://opencontext.org/search/?q=roman&rows=20&start=20",
#   "next-json": "https://opencontext.org/search/.json?q=roman&rows=20&start=20",
#   "last": "https://opencontext.org/search/?q=roman&rows=20&start=77440",
#   "last-json": "https://opencontext.org/search/.json?q=roman&rows=20&start=77440",
#   "oc-api:active-sorting": [
#     {
#       "id": "#current-sort-1",
#       "type": "oc-api:interest-score",
#       "label": "Interest score",
#       "oc-api:sort-order": "descending"
#     }
#   ],
#   "oc-api:has-sorting": [
#     {
#       "id": "https://opencontext.org/search/?q=roman&sort=item--asc",
#       "json": "https://opencontext.org/search/.json?q=roman&sort=item--asc",
#       "type": "oc-api:sort-item",
#       "label": "Item (type, provenance, label)",
#       "oc-api:sort-order": "ascending"
#     },
#     {
#       "id": "https://opencontext.org/search/?q=roman&sort=item--desc",
#       "json": "https://opencontext.org/search/.json?q=roman&sort=item--desc",
#       "type": "oc-api:sort-item",
#       "label": "Item (type, provenance, label)",
#       "oc-api:sort-order": "descending"
#     },
#     {
#       "id": "https://opencontext.org/search/?q=roman&sort=updated--asc",
#       "json": "https://opencontext.org/search/.json?q=roman&sort=updated--asc",
#       "type": "oc-api:sort-updated",
#       "label": "Updated",
#       "oc-api:sort-order": "ascending"
#     },
#     {
#       "id": "https://opencontext.org/search/?q=roman&sort=updated--desc",
#       "json": "https://opencontext.org/search/.json?q=roman&sort=updated--desc",
#       "type": "oc-api:sort-updated",
#       "label": "Updated",
#       "oc-api:sort-order": "descending"
#     }
#   ],
#   "oc-api:active-filters": [
#     {
#       "id": "#filter-1",
#       "oc-api:filter": "Current Text Search Filter",
#       "label": "Search Term: 'roman'",
#       "oc-api:remove": "https://opencontext.org/search/",
#       "oc-api:remove-json": "https://opencontext.org/search/.json"
#     }
#   ],
#   "oc-api:has-text-search": [
#     {
#       "id": "#textfield-keyword-search",
#       "label": "Filter by Text Search",
#       "oc-api:search-term": "roman",
#       "oc-api:template": "https://opencontext.org/search/?q={SearchTerm}",
#       "oc-api:template-json": "https://opencontext.org/search/.json?q={SearchTerm}"
#     }
#   ],
#   "oc-api:has-form-use-life-ranges": [
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000100010101&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000100010101&q=roman",
#       "count": 2,
#       "category": "oc-api:chrono-facet",
#       "start": "-337404",
#       "stop": "1950",
#       "properties": {
#         "early bce/ce": -337405,
#         "late bce/ce": 1950
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000001002013&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000001002013&q=roman",
#       "count": 1,
#       "category": "oc-api:chrono-facet",
#       "start": "-81057",
#       "stop": "-9035",
#       "properties": {
#         "early bce/ce": -81058,
#         "late bce/ce": -9036
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000001101&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000001101&q=roman",
#       "count": 2,
#       "category": "oc-api:chrono-facet",
#       "start": "-15139",
#       "stop": "1950",
#       "properties": {
#         "early bce/ce": -15140,
#         "late bce/ce": 1950
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000001021&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000001021&q=roman",
#       "count": 1,
#       "category": "oc-api:chrono-facet",
#       "start": "-10256",
#       "stop": "-0490",
#       "properties": {
#         "early bce/ce": -10257,
#         "late bce/ce": -491
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000111&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000111&q=roman",
#       "count": 3,
#       "category": "oc-api:chrono-facet",
#       "start": "-7815",
#       "stop": "1950",
#       "properties": {
#         "early bce/ce": -7816,
#         "late bce/ce": 1950
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000112&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000112&q=roman",
#       "count": 6,
#       "category": "oc-api:chrono-facet",
#       "start": "-6594",
#       "stop": "0729",
#       "properties": {
#         "early bce/ce": -6595,
#         "late bce/ce": 729
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000330&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000330&q=roman",
#       "count": 131,
#       "category": "oc-api:chrono-facet",
#       "start": "-6594",
#       "stop": "-5373",
#       "properties": {
#         "early bce/ce": -6595,
#         "late bce/ce": -5374
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000100&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000100&q=roman",
#       "count": 59,
#       "category": "oc-api:chrono-facet",
#       "start": "-4153",
#       "stop": "1950",
#       "properties": {
#         "early bce/ce": -4154,
#         "late bce/ce": 1950
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000120&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000120&q=roman",
#       "count": 5,
#       "category": "oc-api:chrono-facet",
#       "start": "-4153",
#       "stop": "-0490",
#       "properties": {
#         "early bce/ce": -4154,
#         "late bce/ce": -491
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000122&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000122&q=roman",
#       "count": 6,
#       "category": "oc-api:chrono-facet",
#       "start": "-4153",
#       "stop": "-1711",
#       "properties": {
#         "early bce/ce": -4154,
#         "late bce/ce": -1712
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000011&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000011&q=roman",
#       "count": 5,
#       "category": "oc-api:chrono-facet",
#       "start": "-2932",
#       "stop": "1950",
#       "properties": {
#         "early bce/ce": -2933,
#         "late bce/ce": 1950
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000031&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000031&q=roman",
#       "count": 4,
#       "category": "oc-api:chrono-facet",
#       "start": "-2932",
#       "stop": "-0490",
#       "properties": {
#         "early bce/ce": -2933,
#         "late bce/ce": -491
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000010&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000010&q=roman",
#       "count": 5071,
#       "category": "oc-api:chrono-facet",
#       "start": "-1711",
#       "stop": "1950",
#       "properties": {
#         "early bce/ce": -1712,
#         "late bce/ce": 1950
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000012&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000012&q=roman",
#       "count": 3818,
#       "category": "oc-api:chrono-facet",
#       "start": "-1711",
#       "stop": "0729",
#       "properties": {
#         "early bce/ce": -1712,
#         "late bce/ce": 729
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000030&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000030&q=roman",
#       "count": 149,
#       "category": "oc-api:chrono-facet",
#       "start": "-1711",
#       "stop": "-0490",
#       "properties": {
#         "early bce/ce": -1712,
#         "late bce/ce": -491
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000001&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000001&q=roman",
#       "count": 59097,
#       "category": "oc-api:chrono-facet",
#       "start": "-0490",
#       "stop": "1950",
#       "properties": {
#         "early bce/ce": -491,
#         "late bce/ce": 1950
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000003&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000003&q=roman",
#       "count": 5732,
#       "category": "oc-api:chrono-facet",
#       "start": "-0490",
#       "stop": "0729",
#       "properties": {
#         "early bce/ce": -491,
#         "late bce/ce": 729
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?form-chronotile=10M-0000000000000&q=roman",
#       "json": "https://opencontext.org/search/.json?form-chronotile=10M-0000000000000&q=roman",
#       "count": 251,
#       "category": "oc-api:chrono-facet",
#       "start": "0729",
#       "stop": "1950",
#       "properties": {
#         "early bce/ce": 729,
#         "late bce/ce": 1950
#       }
#     }
#   ],
#   "oc-api:max-disc-tile-zoom": 20,
#   "oc-api:response-tile-zoom": 6,
#   "oc-api:geotile-scope": null,
#   "oc-api:has-facets": [
#     {
#       "id": "#facet-context",
#       "rdfs:isDefinedBy": "oc-api:facet-context",
#       "label": "Context",
#       "data-type": "id",
#       "type": "oc-api:facet-context",
#       "oc-api:has-id-options": [
#         {
#           "id": "https://opencontext.org/search/Turkey?q=roman",
#           "json": "https://opencontext.org/search/Turkey.json?q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/subjects/1_Global_Spatial",
#           "label": "Turkey",
#           "count": 52876,
#           "slug": "turkey"
#         },
#         {
#           "id": "https://opencontext.org/search/Cyprus?q=roman",
#           "json": "https://opencontext.org/search/Cyprus.json?q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/subjects/67D9F00D-14E6-4A1B-3A61-EC92FC774098",
#           "label": "Cyprus",
#           "count": 8822,
#           "slug": "cyprus"
#         },
#         {
#           "id": "https://opencontext.org/search/Italy?q=roman",
#           "json": "https://opencontext.org/search/Italy.json?q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/subjects/B66A08F2-5D96-4DD4-1AB1-32880C9A8D9D",
#           "label": "Italy",
#           "count": 5065,
#           "slug": "italy"
#         },
#         {
#           "id": "https://opencontext.org/search/Jordan?q=roman",
#           "json": "https://opencontext.org/search/Jordan.json?q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/subjects/D9AE02E5-C3F3-41D0-EB3A-39798F63GGGG",
#           "label": "Jordan",
#           "count": 2777,
#           "slug": "jordan"
#         },
#         {
#           "id": "https://opencontext.org/search/Germany?q=roman",
#           "json": "https://opencontext.org/search/Germany.json?q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/subjects/2_Global_Germany",
#           "label": "Germany",
#           "count": 457,
#           "slug": "germany"
#         },
#         {
#           "id": "https://opencontext.org/search/Egypt?q=roman",
#           "json": "https://opencontext.org/search/Egypt.json?q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/subjects/A2257E54-3B4F-4DA5-0E50-A428ECEB47A2",
#           "label": "Egypt",
#           "count": 179,
#           "slug": "egypt"
#         },
#         {
#           "id": "https://opencontext.org/search/Israel?q=roman",
#           "json": "https://opencontext.org/search/Israel.json?q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/subjects/3_Global_Israel",
#           "label": "Israel",
#           "count": 79,
#           "slug": "israel"
#         },
#         {
#           "id": "https://opencontext.org/search/Palestinian+Authority?q=roman",
#           "json": "https://opencontext.org/search/Palestinian+Authority.json?q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/subjects/4_global_Palestine",
#           "label": "Palestinian Authority",
#           "count": 39,
#           "slug": "palestinian-authority"
#         },
#         {
#           "id": "https://opencontext.org/search/Poland?q=roman",
#           "json": "https://opencontext.org/search/Poland.json?q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/subjects/a2f952b7-baef-49d8-9cfb-c32a630ac64e",
#           "label": "Poland",
#           "count": 39,
#           "slug": "poland"
#         },
#         {
#           "id": "https://opencontext.org/search/Spain?q=roman",
#           "json": "https://opencontext.org/search/Spain.json?q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/subjects/3776e3e7-91ea-4c35-9481-0b1fae3afa9a",
#           "label": "Spain",
#           "count": 28,
#           "slug": "spain"
#         },
#         {
#           "id": "https://opencontext.org/search/United+States?q=roman",
#           "json": "https://opencontext.org/search/United+States.json?q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/subjects/2A1B75E6-8C79-49B9-873A-A2E006669691",
#           "label": "United States",
#           "count": 12,
#           "slug": "united-states"
#         },
#         {
#           "id": "https://opencontext.org/search/Mexico?q=roman",
#           "json": "https://opencontext.org/search/Mexico.json?q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/subjects/ee431393-7ab1-4d7a-abec-bb05f53babda",
#           "label": "Mexico",
#           "count": 1,
#           "slug": "mexico"
#         }
#       ]
#     },
#     {
#       "id": "#facet-item-type",
#       "rdfs:isDefinedBy": "oc-api:facet-item-type",
#       "label": "Open Context Type",
#       "data-type": "id",
#       "type": "oc-api:facet-item-type",
#       "oc-api:has-id-options": [
#         {
#           "id": "https://opencontext.org/search/?q=roman&type=subjects",
#           "json": "https://opencontext.org/search/.json?q=roman&type=subjects",
#           "rdfs:isDefinedBy": "oc-gen:subjects",
#           "label": "Subjects",
#           "count": 57603,
#           "slug": "subjects"
#         },
#         {
#           "id": "https://opencontext.org/search/?q=roman&type=media",
#           "json": "https://opencontext.org/search/.json?q=roman&type=media",
#           "rdfs:isDefinedBy": "oc-gen:media",
#           "label": "Media",
#           "count": 13703,
#           "slug": "media"
#         },
#         {
#           "id": "https://opencontext.org/search/?q=roman&type=types",
#           "json": "https://opencontext.org/search/.json?q=roman&type=types",
#           "rdfs:isDefinedBy": "oc-gen:types",
#           "label": "Descriptive types",
#           "count": 4341,
#           "slug": "types"
#         },
#         {
#           "id": "https://opencontext.org/search/?q=roman&type=predicates",
#           "json": "https://opencontext.org/search/.json?q=roman&type=predicates",
#           "rdfs:isDefinedBy": "oc-gen:predicates",
#           "label": "Predicates or properties",
#           "count": 1008,
#           "slug": "predicates"
#         },
#         {
#           "id": "https://opencontext.org/search/?q=roman&type=documents",
#           "json": "https://opencontext.org/search/.json?q=roman&type=documents",
#           "rdfs:isDefinedBy": "oc-gen:documents",
#           "label": "Documents",
#           "count": 526,
#           "slug": "documents"
#         },
#         {
#           "id": "https://opencontext.org/search/?q=roman&type=persons",
#           "json": "https://opencontext.org/search/.json?q=roman&type=persons",
#           "rdfs:isDefinedBy": "oc-gen:persons",
#           "label": "Persons or Organizations",
#           "count": 261,
#           "slug": "persons"
#         },
#         {
#           "id": "https://opencontext.org/search/?q=roman&type=projects",
#           "json": "https://opencontext.org/search/.json?q=roman&type=projects",
#           "rdfs:isDefinedBy": "oc-gen:projects",
#           "label": "Projects or Collections",
#           "count": 16,
#           "slug": "projects"
#         },
#         {
#           "id": "https://opencontext.org/search/?q=roman&type=tables",
#           "json": "https://opencontext.org/search/.json?q=roman&type=tables",
#           "rdfs:isDefinedBy": "oc-gen:tables",
#           "label": "Tables",
#           "count": 2,
#           "slug": "tables"
#         }
#       ]
#     },
#     {
#       "id": "#facet-prop-oc-gen-subjects",
#       "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/oc-general/subjects",
#       "label": "(Related) Subjects",
#       "slug": "rel--oc-gen-subjects",
#       "data-type": "id",
#       "type": "oc-api:facet-prop",
#       "oc-api:has-id-options": [
#         {
#           "id": "https://opencontext.org/search/?prop=rel--oc-gen-cat-loc-or-context&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=rel--oc-gen-cat-loc-or-context&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/oc-general/cat-loc-or-context",
#           "label": "Location or Context",
#           "count": 7858,
#           "slug": "rel--oc-gen-cat-loc-or-context"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=rel--oc-gen-cat-object&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=rel--oc-gen-cat-object&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/oc-general/cat-object",
#           "label": "Object",
#           "count": 3255,
#           "slug": "rel--oc-gen-cat-object"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=rel--oc-gen-cat-sample-col&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=rel--oc-gen-cat-sample-col&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/oc-general/cat-sample-col",
#           "label": "Sample, Collection, or Aggregation",
#           "count": 2090,
#           "slug": "rel--oc-gen-cat-sample-col"
#         }
#       ]
#     },
#     {
#       "id": "#facet-project",
#       "rdfs:isDefinedBy": "oc-api:facet-project",
#       "label": "Project",
#       "data-type": "id",
#       "type": "oc-api:facet-project",
#       "oc-api:has-id-options": [
#         {
#           "id": "https://opencontext.org/search/?proj=117-avkat-archaeological-project&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=117-avkat-archaeological-project&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/02b55e8c-e9b1-49e5-8edf-0afeea10e2be",
#           "label": "Avkat Archaeological Project",
#           "count": 51985,
#           "slug": "117-avkat-archaeological-project"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=24-murlo&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=24-murlo&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/DF043419-F23B-41DA-7E4D-EE52AF22F92F",
#           "label": "Murlo",
#           "count": 9179,
#           "slug": "24-murlo"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=42-pyla-koutsopetria-archaeological-project-i-pedestrian&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=42-pyla-koutsopetria-archaeological-project-i-pedestrian&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/3F6DCD13-A476-488E-ED10-47D25513FCB2",
#           "label": "Pyla-Koutsopetria Archaeological Project I: Pedestrian Survey",
#           "count": 6199,
#           "slug": "42-pyla-koutsopetria-archaeological-project-i-pedestrian"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=10-petra-great-temple-excavations&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=10-petra-great-temple-excavations&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/A5DDBEA2-B3C8-43F9-8151-33343CBDC857",
#           "label": "Petra Great Temple Excavations",
#           "count": 2939,
#           "slug": "10-petra-great-temple-excavations"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=125-pyla-koutsopetria-archaeological-project-ii-geophysics&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=125-pyla-koutsopetria-archaeological-project-ii-geophysics&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/b9472eec-e622-4838-b6d8-5a2958b9d4d3",
#           "label": "Pyla-Koutsopetria Archaeological Project II: Geophysics and Excavation",
#           "count": 2583,
#           "slug": "125-pyla-koutsopetria-archaeological-project-ii-geophysics"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=104-the-gabii-project&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=104-the-gabii-project&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd",
#           "label": "The Gabii Project",
#           "count": 2437,
#           "slug": "104-the-gabii-project"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=11-aegean-archaeomalacology&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=11-aegean-archaeomalacology&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/B1DAC335-4DC6-4A57-622E-75BF28BA598D",
#           "label": "Aegean Archaeomalacology",
#           "count": 977,
#           "slug": "11-aegean-archaeomalacology"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=65-biometrical-database-of-european-aurochs-and-domestic-c&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=65-biometrical-database-of-european-aurochs-and-domestic-c&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/1816A043-92E2-471D-A23D-AAC58695D0D3",
#           "label": "Biometrical Database of European Aurochs and Domestic Cattle",
#           "count": 526,
#           "slug": "65-biometrical-database-of-european-aurochs-and-domestic-c"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=101-arce-sphinx-project-1979-1983-archive&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=101-arce-sphinx-project-1979-1983-archive&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#           "label": "ARCE Sphinx Project 1979-1983 Archive",
#           "count": 184,
#           "slug": "101-arce-sphinx-project-1979-1983-archive"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=63-excavations-at-polis&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=63-excavations-at-polis&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/766d9fd5-2175-41e3-b7c9-7eba6777f1f0",
#           "label": "Excavations at Polis",
#           "count": 138,
#           "slug": "63-excavations-at-polis"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=35-catalhoyuk-area-tp-zooarchaeology&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=35-catalhoyuk-area-tp-zooarchaeology&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/02594C48-7497-40D7-11AE-AB942DC513B8",
#           "label": "\u00c7atalh\u00f6y\u00fck Area TP Zooarchaeology",
#           "count": 123,
#           "slug": "35-catalhoyuk-area-tp-zooarchaeology"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=112-tel-dor-area-g-report&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=112-tel-dor-area-g-report&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/b028c160-092e-4e2d-9738-a40367ad543b",
#           "label": "Tel Dor, Area G Report",
#           "count": 65,
#           "slug": "112-tel-dor-area-g-report"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=14-bade-museum&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=14-bade-museum&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/B4345F6A-F926-4062-144E-3FBC175CC7B6",
#           "label": "Bade Museum",
#           "count": 46,
#           "slug": "14-bade-museum"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=22-kenan-tepe&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=22-kenan-tepe&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/3DE4CD9C-259E-4C14-9B03-8B10454BA66E",
#           "label": "Kenan Tepe",
#           "count": 15,
#           "slug": "22-kenan-tepe"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=93-biometry-of-iron-age-ii-and-hellenistic-period-dog-bur&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=93-biometry-of-iron-age-ii-and-hellenistic-period-dog-bur&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/646b7034-07b7-4971-8d89-ebe37dda4cd2",
#           "label": "Biometry of Iron Age II and Hellenistic Period Dog 'Burials' from Tell Gezer and Other Sites",
#           "count": 15,
#           "slug": "93-biometry-of-iron-age-ii-and-hellenistic-period-dog-bur"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=1-domuztepe-excavations&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=1-domuztepe-excavations&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/3",
#           "label": "Domuztepe Excavations",
#           "count": 14,
#           "slug": "1-domuztepe-excavations"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=52-digital-index-of-north-american-archaeology-dinaa&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=52-digital-index-of-north-american-archaeology-dinaa&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/416A274C-CF88-4471-3E31-93DB825E9E4A",
#           "label": "Digital Index of North American Archaeology (DINAA)",
#           "count": 7,
#           "slug": "52-digital-index-of-north-american-archaeology-dinaa"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=91-historic-fort-snelling&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=91-historic-fort-snelling&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/fab0532a-2953-4f13-aa97-8a9d7e992dbe",
#           "label": "Historic Fort Snelling",
#           "count": 6,
#           "slug": "91-historic-fort-snelling"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=99-idalion&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=99-idalion&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/df8e4efd-e06b-4b0b-a056-08b6fd199536",
#           "label": "Idalion",
#           "count": 6,
#           "slug": "99-idalion"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=39-ceramics-trade-provenience-and-geology-cyprus-in-the&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=39-ceramics-trade-provenience-and-geology-cyprus-in-the&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/ABABD13C-A69F-499E-CA7F-5118F3684E4D",
#           "label": "Ceramics, Trade, Provenience and Geology: Cyprus in the Late Bronze Age",
#           "count": 5,
#           "slug": "39-ceramics-trade-provenience-and-geology-cyprus-in-the"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=109-differentiating-local-from-nonlocal-ceramic-production&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=109-differentiating-local-from-nonlocal-ceramic-production&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/cbd24bbb-c6fc-44ed-bd67-6f844f120ad5",
#           "label": "Differentiating local from nonlocal ceramic production at Iron Age Sardis using NAA",
#           "count": 3,
#           "slug": "109-differentiating-local-from-nonlocal-ceramic-production"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=100-paleoindian-database-of-the-americas-pidba&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=100-paleoindian-database-of-the-americas-pidba&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/d75ef68a-0e23-458c-976d-286d83c13013",
#           "label": "Paleoindian Database of the Americas (PIDBA)",
#           "count": 1,
#           "slug": "100-paleoindian-database-of-the-americas-pidba"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=103-architecture-and-urbanism-at-seyitomer-hoyuk-turkey&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=103-architecture-and-urbanism-at-seyitomer-hoyuk-turkey&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/347286db-b6c6-4fd2-b3bd-b50316b0cb9f",
#           "label": "Architecture and Urbanism at Seyit\u00f6mer H\u00f6y\u00fck, Turkey",
#           "count": 1,
#           "slug": "103-architecture-and-urbanism-at-seyitomer-hoyuk-turkey"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=20-dhiban-excavation-and-development-project&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=20-dhiban-excavation-and-development-project&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/01D080DF-2F6B-4F59-BCF0-87543AC89574",
#           "label": "Dhiban Excavation and Development Project",
#           "count": 1,
#           "slug": "20-dhiban-excavation-and-development-project"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=21-rough-cilicia&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=21-rough-cilicia&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/295B5BF4-0F44-4698-80CD-7A39CB6F133D",
#           "label": "Rough Cilicia",
#           "count": 1,
#           "slug": "21-rough-cilicia"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=26-zooarchaeology-of-karain-cave-b&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=26-zooarchaeology-of-karain-cave-b&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/731B0670-CE2A-414A-8EF6-9C050A1C60F5",
#           "label": "Zooarchaeology of Karain Cave B",
#           "count": 1,
#           "slug": "26-zooarchaeology-of-karain-cave-b"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=31-barcin-hoyuk-zooarchaeology&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=31-barcin-hoyuk-zooarchaeology&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/74749949-4FD4-4C3E-C830-5AA75703E08E",
#           "label": "Bar\u00e7\u0131n H\u00f6y\u00fck Zooarchaeology",
#           "count": 1,
#           "slug": "31-barcin-hoyuk-zooarchaeology"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=36-ilipinar-zooarchaeology&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=36-ilipinar-zooarchaeology&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/D297CD29-50CA-4B2C-4A07-498ADF3AF487",
#           "label": "Il\u0131p\u0131nar Zooarchaeology",
#           "count": 1,
#           "slug": "36-ilipinar-zooarchaeology"
#         },
#         {
#           "id": "https://opencontext.org/search/?proj=9-iraq-heritage-program&q=roman",
#           "json": "https://opencontext.org/search/.json?proj=9-iraq-heritage-program&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/projects/GHF1PRJ0000000025",
#           "label": "Iraq Heritage Program",
#           "count": 1,
#           "slug": "9-iraq-heritage-program"
#         }
#       ]
#     },
#     {
#       "id": "#facet-prop-ld",
#       "rdfs:isDefinedBy": "oc-api:facet-prop-ld",
#       "label": "Descriptions (Common Standards)",
#       "data-type": "id",
#       "type": "oc-api:facet-prop",
#       "oc-api:has-id-options": [
#         {
#           "id": "https://opencontext.org/search/?prop=dc-terms-temporal&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-temporal&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/temporal",
#           "label": "Temporal Coverage",
#           "count": 63787,
#           "slug": "dc-terms-temporal"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=cidoc-crm-p2-has-type&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=cidoc-crm-p2-has-type&q=roman",
#           "rdfs:isDefinedBy": "http://erlangen-crm.org/current/P2_has_type",
#           "label": "Has type",
#           "count": 7824,
#           "slug": "cidoc-crm-p2-has-type"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=skos-related&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=skos-related&q=roman",
#           "rdfs:isDefinedBy": "http://www.w3.org/2004/02/skos/core#related",
#           "label": "Related",
#           "count": 4410,
#           "slug": "skos-related"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=rel--cidoc-crm-p2-has-type&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=rel--cidoc-crm-p2-has-type&q=roman",
#           "rdfs:isDefinedBy": "http://erlangen-crm.org/current/P2_has_type",
#           "label": "Has type",
#           "count": 3550,
#           "slug": "rel--cidoc-crm-p2-has-type"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=cidoc-crm-p45-consists-of&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=cidoc-crm-p45-consists-of&q=roman",
#           "rdfs:isDefinedBy": "http://erlangen-crm.org/current/P45_consists_of",
#           "label": "Consists of",
#           "count": 2933,
#           "slug": "cidoc-crm-p45-consists-of"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=rel--cidoc-crm-p45-consists-of&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=rel--cidoc-crm-p45-consists-of&q=roman",
#           "rdfs:isDefinedBy": "http://erlangen-crm.org/current/P45_consists_of",
#           "label": "Consists of",
#           "count": 1455,
#           "slug": "rel--cidoc-crm-p45-consists-of"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=oc-zoo-has-anat-id&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=oc-zoo-has-anat-id&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/open-context-zooarch/has-anat-id",
#           "label": "Has anatomical identification",
#           "count": 988,
#           "slug": "oc-zoo-has-anat-id"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=biol-term-hastaxonomy&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=biol-term-hastaxonomy&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/NET/biol/ns#term_hasTaxonomy",
#           "label": "Has Biological Taxonomy",
#           "count": 964,
#           "slug": "biol-term-hastaxonomy"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=oc-zoo-anatomical-meas&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=oc-zoo-anatomical-meas&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/open-context-zooarch/anatomical-meas",
#           "label": "Anatomical measurement",
#           "count": 542,
#           "slug": "oc-zoo-anatomical-meas"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=dc-terms-references&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-references&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/references",
#           "label": "References",
#           "count": 527,
#           "slug": "dc-terms-references"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=oc-zoo-has-fusion-char&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=oc-zoo-has-fusion-char&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/open-context-zooarch/has-fusion-char",
#           "label": "Has fusion character",
#           "count": 521,
#           "slug": "oc-zoo-has-fusion-char"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=dc-terms-ispartof&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-ispartof&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/isPartOf",
#           "label": "Is Part Of",
#           "count": 491,
#           "slug": "dc-terms-ispartof"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=skos-closematch&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=skos-closematch&q=roman",
#           "rdfs:isDefinedBy": "http://www.w3.org/2004/02/skos/core#closeMatch",
#           "label": "Close Match",
#           "count": 429,
#           "slug": "skos-closematch"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=rel--gawd-origin&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=rel--gawd-origin&q=roman",
#           "rdfs:isDefinedBy": "http://gawd.atlantides.org/terms/origin",
#           "label": "Origin place",
#           "count": 137,
#           "slug": "rel--gawd-origin"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=rel--dc-terms-subject&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=rel--dc-terms-subject&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/subject",
#           "label": "Subject",
#           "count": 125,
#           "slug": "rel--dc-terms-subject"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=gawd-origin&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=gawd-origin&q=roman",
#           "rdfs:isDefinedBy": "http://gawd.atlantides.org/terms/origin",
#           "label": "Origin place",
#           "count": 70,
#           "slug": "gawd-origin"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=dc-terms-subject&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-subject&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/subject",
#           "label": "Subject",
#           "count": 50,
#           "slug": "dc-terms-subject"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=dc-terms-isreferencedby&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-isreferencedby&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/isReferencedBy",
#           "label": "Is Referenced By",
#           "count": 18,
#           "slug": "dc-terms-isreferencedby"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=dc-terms-haspart&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-haspart&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/hasPart",
#           "label": "Has Part",
#           "count": 17,
#           "slug": "dc-terms-haspart"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=bibo-status&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=bibo-status&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/ontology/bibo/status",
#           "label": "Status",
#           "count": 16,
#           "slug": "bibo-status"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=dc-terms-spatial&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-spatial&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/spatial",
#           "label": "Spatial",
#           "count": 14,
#           "slug": "dc-terms-spatial"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=dc-terms-coverage&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-coverage&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/coverage",
#           "label": "Coverage",
#           "count": 11,
#           "slug": "dc-terms-coverage"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=oc-zoo-has-phys-sex-det&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=oc-zoo-has-phys-sex-det&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/open-context-zooarch/has-phys-sex-det",
#           "label": "Has physiological sex determination",
#           "count": 8,
#           "slug": "oc-zoo-has-phys-sex-det"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=dinaa-00001&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=dinaa-00001&q=roman",
#           "rdfs:isDefinedBy": "http://opencontext.org/vocabularies/dinaa/00001",
#           "label": "Has period",
#           "count": 6,
#           "slug": "dinaa-00001"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=rel--dc-terms-references&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=rel--dc-terms-references&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/references",
#           "label": "References",
#           "count": 4,
#           "slug": "rel--dc-terms-references"
#         }
#       ],
#       "oc-api:has-text-options": [
#         {
#           "id": "https://opencontext.org/search/?prop=rel--skos-altlabel&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=rel--skos-altlabel&q=roman",
#           "rdfs:isDefinedBy": "http://www.w3.org/2004/02/skos/core#altLabel",
#           "label": "Alternative label",
#           "count": 133,
#           "slug": "rel--skos-altlabel"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=skos-altlabel&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=skos-altlabel&q=roman",
#           "rdfs:isDefinedBy": "http://www.w3.org/2004/02/skos/core#altLabel",
#           "label": "Alternative label",
#           "count": 6,
#           "slug": "skos-altlabel"
#         },
#         {
#           "id": "https://opencontext.org/search/?prop=dc-terms-identifier&q=roman",
#           "json": "https://opencontext.org/search/.json?prop=dc-terms-identifier&q=roman",
#           "rdfs:isDefinedBy": "http://purl.org/dc/terms/identifier",
#           "label": "Identifier",
#           "count": 3,
#           "slug": "dc-terms-identifier"
#         }
#       ]
#     },
#     {
#       "id": "#related-media",
#       "label": "Has Related Media",
#       "oc-api:has-rel-media-options": [
#         {
#           "id": "https://opencontext.org/search/?images=1&q=roman",
#           "json": "https://opencontext.org/search/.json?images=1&q=roman",
#           "label": "Linked with images",
#           "count": 3348
#         },
#         {
#           "id": "https://opencontext.org/search/?other-media=1&q=roman",
#           "json": "https://opencontext.org/search/.json?other-media=1&q=roman",
#           "label": "Linked with media (non-image)",
#           "count": 108
#         },
#         {
#           "id": "https://opencontext.org/search/?documents=1&q=roman",
#           "json": "https://opencontext.org/search/.json?documents=1&q=roman",
#           "label": "Linked with documents",
#           "count": 19
#         }
#       ]
#     }
#   ],
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "id": "https://opencontext.org/search/?disc-geotile=021333&q=roman",
#       "json": "https://opencontext.org/search/.json?disc-geotile=021333&q=roman",
#       "count": 6,
#       "type": "Feature",
#       "category": "oc-api:geo-facet",
#       "when": {
#         "id": "#event-021333",
#         "type": "oc-gen:formation-use-life",
#         "start": "-336999",
#         "stop": "1950"
#       },
#       "geometry": {
#         "id": "#geo-disc-tile-geom-021333",
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -95.625,
#               40.979898069620155
#             ],
#             [
#               -90.0,
#               40.979898069620155
#             ],
#             [
#               -90.0,
#               45.089035564831015
#             ],
#             [
#               -95.625,
#               45.089035564831015
#             ],
#             [
#               -95.625,
#               40.979898069620155
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "id": "#geo-disc-tile-021333",
#         "href": "https://opencontext.org/search/?disc-geotile=021333&q=roman",
#         "label": "Discovery region (1)",
#         "feature-type": "discovery region (facet)",
#         "count": 6,
#         "early bce/ce": -337000,
#         "late bce/ce": 1950
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?disc-geotile=023131&q=roman",
#       "json": "https://opencontext.org/search/.json?disc-geotile=023131&q=roman",
#       "count": 3,
#       "type": "Feature",
#       "category": "oc-api:geo-facet",
#       "when": {
#         "id": "#event-023131",
#         "type": "oc-gen:formation-use-life",
#         "start": "-336999",
#         "stop": "1950"
#       },
#       "geometry": {
#         "id": "#geo-disc-tile-geom-023131",
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -95.625,
#               27.059125784374068
#             ],
#             [
#               -90.0,
#               27.059125784374068
#             ],
#             [
#               -90.0,
#               31.952162238024975
#             ],
#             [
#               -95.625,
#               31.952162238024975
#             ],
#             [
#               -95.625,
#               27.059125784374068
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "id": "#geo-disc-tile-023131",
#         "href": "https://opencontext.org/search/?disc-geotile=023131&q=roman",
#         "label": "Discovery region (2)",
#         "feature-type": "discovery region (facet)",
#         "count": 3,
#         "early bce/ce": -337000,
#         "late bce/ce": 1950
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?disc-geotile=023301&q=roman",
#       "json": "https://opencontext.org/search/.json?disc-geotile=023301&q=roman",
#       "count": 1,
#       "type": "Feature",
#       "category": "oc-api:geo-facet",
#       "when": {
#         "id": "#event-023301",
#         "type": "oc-gen:formation-use-life",
#         "start": "-336999",
#         "stop": "1950"
#       },
#       "geometry": {
#         "id": "#geo-disc-tile-geom-023301",
#         "type": "Polygon",
#         "coordinates": [
#           [
#             [
#               -106.875,
#               16.636191878397664
#             ],
#             [
#               -101.25,
#               16.636191878397664
#             ],
#             [
#               -101.25,
#               21.943045533438166
#             ],
#             [
#               -106.875,
#               21.943045533438166
#             ],
#             [
#               -106.875,
#               16.636191878397664
#             ]
#           ]
#         ]
#       },
#       "properties": {
#         "id": "#geo-disc-tile-023301",
#         "href": "https://opencontext.org/search/?disc-geotile=023301&q=roman",
#         "label": "Discovery region (3)",
#         "feature-type": "discovery region (facet)",
#         "count": 1,
#         "early bce/ce": -337000,
#         "late bce/ce": 1950
#       }
#     },
#     {
#       "id": "https://opencontext.org/search/?disc-geotile=030222&q=roman",
# ...
#         "snippet": "Drawing d-e-021 from Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/<em>Roman</em> Pavement/Removal",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-e-021.jpg",
#         "published": "2017-12-23T01:01:34Z",
#         "updated": "2018-03-23T01:02:54Z"
#       }
#     },
#     {
#       "id": "#record-11-of-77460",
#       "label": "Drawing d-gen-011",
#       "rdfs:isDefinedBy": "http://opencontext.org/media/e4c24bfd-6199-4d66-9af2-392ee138a247",
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#geo-rec-geom-11-of-77460",
#         "type": "Point",
#         "coordinates": [
#           31.13832000374021,
#           29.975190517527544
#         ]
#       },
#       "properties": {
#         "id": "#rec-11-of-77460",
#         "feature-type": "item record",
#         "uri": "http://opencontext.org/media/e4c24bfd-6199-4d66-9af2-392ee138a247",
#         "href": "https://opencontext.org/media/e4c24bfd-6199-4d66-9af2-392ee138a247",
#         "citation uri": false,
#         "label": "Drawing d-gen-011",
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "context label": "Egypt/Giza/Terrace 1/Sphinx Temple",
#         "context href": "https://opencontext.org/subjects/1a934b66-8bd6-476e-94c1-fdb51c456aa9",
#         "early bce/ce": false,
#         "late bce/ce": false,
#         "item category": "Image",
#         "snippet": " including: Sphinx Temple NW Corner, Sphinx North Forepaw, Pavement, <em>Roman</em> Stairs, North Ledge, Amenhotep II",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings-B/d-gen-011.jpg",
#         "published": "2017-12-23T01:02:55Z",
#         "updated": "2018-03-23T01:20:43Z"
#       }
#     },
#     {
#       "id": "#record-12-of-77460",
#       "label": "Drawing d-e-024",
#       "rdfs:isDefinedBy": "http://opencontext.org/media/af4246af-16a1-4770-b00a-f16f774dacf9",
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#geo-rec-geom-12-of-77460",
#         "type": "Point",
#         "coordinates": [
#           31.137937830616877,
#           29.97526657483614
#         ]
#       },
#       "properties": {
#         "id": "#rec-12-of-77460",
#         "feature-type": "item record",
#         "uri": "http://opencontext.org/media/af4246af-16a1-4770-b00a-f16f774dacf9",
#         "href": "https://opencontext.org/media/af4246af-16a1-4770-b00a-f16f774dacf9",
#         "citation uri": false,
#         "label": "Drawing d-e-024",
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Removal 14",
#         "context href": "https://opencontext.org/subjects/37cbe2aa-1877-4eba-b3a5-45c43d13abc9",
#         "early bce/ce": false,
#         "late bce/ce": false,
#         "item category": "Image",
#         "snippet": " amount of deposits immediately south of the <em>Roman</em> Stairs, between the stairs and the Sound and Light box",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-e-024.jpg",
#         "published": "2017-12-23T01:01:36Z",
#         "updated": "2018-03-23T01:02:37Z"
#       }
#     },
#     {
#       "id": "#record-13-of-77460",
#       "label": "2672",
#       "rdfs:isDefinedBy": "http://opencontext.org/media/99496876-67e8-408f-8da6-212f515ef67f",
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#geo-rec-geom-13-of-77460",
#         "type": "Point",
#         "coordinates": [
#           12.719486146888293,
#           41.88774442934475
#         ]
#       },
#       "when": {
#         "id": "#event-rec-when-13-of-77460",
#         "type": "oc-gen:formation-use-life",
#         "start": "-0674",
#         "stop": "0001"
#       },
#       "properties": {
#         "id": "#rec-13-of-77460",
#         "feature-type": "item record",
#         "uri": "http://opencontext.org/media/99496876-67e8-408f-8da6-212f515ef67f",
#         "href": "https://opencontext.org/media/99496876-67e8-408f-8da6-212f515ef67f",
#         "citation uri": false,
#         "label": "2672",
#         "project label": "The Gabii Project",
#         "project href": "https://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd",
#         "context label": "Italy/Gabii/Area B/Unit 1242",
#         "context href": "https://opencontext.org/subjects/4d680e71-b622-42eb-9577-bd0eec2a8251",
#         "early bce/ce": -675.0,
#         "late bce/ce": 1.0,
#         "item category": "Image",
#         "snippet": " Priority  Medium  \n File Attachment Filename 2672.pdf \n \n<em>Roman</em> Republican\nhttp://n2t.net/ark:/99152",
#         "thumbnail": "https://opencontext.org/static/oc/images/icons/3d-noun-37529.png",
#         "published": "2017-06-04T23:26:17Z",
#         "updated": "2018-01-31T08:20:27Z"
#       }
#     },
#     {
#       "id": "#record-14-of-77460",
#       "label": "2770",
#       "rdfs:isDefinedBy": "http://opencontext.org/media/9d2ca9a6-127a-475f-8698-6acaf47f3967",
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#geo-rec-geom-14-of-77460",
#         "type": "Point",
#         "coordinates": [
#           12.719685707676424,
#           41.88771672158477
#         ]
#       },
#       "when": {
#         "id": "#event-rec-when-14-of-77460",
#         "type": "oc-gen:formation-use-life",
#         "start": "-0899",
#         "stop": "0200"
#       },
#       "properties": {
#         "id": "#rec-14-of-77460",
#         "feature-type": "item record",
#         "uri": "http://opencontext.org/media/9d2ca9a6-127a-475f-8698-6acaf47f3967",
#         "href": "https://opencontext.org/media/9d2ca9a6-127a-475f-8698-6acaf47f3967",
#         "citation uri": false,
#         "label": "2770",
#         "project label": "The Gabii Project",
#         "project href": "https://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd",
#         "context label": "Italy/Gabii/Area B/Unit 1386",
#         "context href": "https://opencontext.org/subjects/321b8a74-9782-450b-93e2-82d963cb2f8f",
#         "early bce/ce": -900.0,
#         "late bce/ce": 200.0,
#         "item category": "Image",
#         "snippet": "  Medium  \n File Attachment Filename 2770.pdf \n \n<em>Roman</em> Republican\nhttp://n2t.net/ark:/99152/p0qhb66mvjk",
#         "thumbnail": "https://opencontext.org/static/oc/images/icons/3d-noun-37529.png",
#         "published": "2017-06-04T23:32:24Z",
#         "updated": "2018-01-31T08:18:05Z"
#       }
#     },
#     {
#       "id": "#record-15-of-77460",
#       "label": "Drawing d-e-042",
#       "rdfs:isDefinedBy": "http://opencontext.org/media/f9d43eb2-12bd-4f8a-9f78-4ecba5406e07",
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#geo-rec-geom-15-of-77460",
#         "type": "Point",
#         "coordinates": [
#           31.137937830616877,
#           29.97526657483614
#         ]
#       },
#       "properties": {
#         "id": "#rec-15-of-77460",
#         "feature-type": "item record",
#         "uri": "http://opencontext.org/media/f9d43eb2-12bd-4f8a-9f78-4ecba5406e07",
#         "href": "https://opencontext.org/media/f9d43eb2-12bd-4f8a-9f78-4ecba5406e07",
#         "citation uri": false,
#         "label": "Drawing d-e-042",
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East",
#         "context href": "https://opencontext.org/subjects/5714b49e-a383-4738-9235-29841bfaaba0",
#         "early bce/ce": false,
#         "late bce/ce": false,
#         "item category": "Image",
#         "snippet": "  \n Resource Type  Drawings  \n Keywords  Chapel  Forepaws  Masonry  <em>Roman</em> Pavement  \n Scale 1:50 \n \n Creator",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings-B/d-e-042.jpg",
#         "published": "2017-12-23T01:01:46Z",
#         "updated": "2018-03-23T01:06:48Z"
#       }
#     },
#     {
#       "id": "#record-16-of-77460",
#       "label": "Drawing d-e-066",
#       "rdfs:isDefinedBy": "http://opencontext.org/media/8b650f2e-2196-45d1-aa17-535943293d23",
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#geo-rec-geom-16-of-77460",
#         "type": "Point",
#         "coordinates": [
#           31.137937830616877,
#           29.97526657483614
#         ]
#       },
#       "properties": {
#         "id": "#rec-16-of-77460",
#         "feature-type": "item record",
#         "uri": "http://opencontext.org/media/8b650f2e-2196-45d1-aa17-535943293d23",
#         "href": "https://opencontext.org/media/8b650f2e-2196-45d1-aa17-535943293d23",
#         "citation uri": "http://n2t.net/ark:/28722/k2nv9pv9c",
#         "label": "Drawing d-e-066",
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Removal 14",
#         "context href": "https://opencontext.org/subjects/37cbe2aa-1877-4eba-b3a5-45c43d13abc9",
#         "early bce/ce": false,
#         "late bce/ce": false,
#         "item category": "Image",
#         "snippet": ") R14 \n \n Description R14 was the removal of a small amount of deposits immediately south of the <em>Roman</em>",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings-B/d-e-066.jpg",
#         "published": "2017-12-23T01:02:02Z",
#         "updated": "2018-03-23T01:04:33Z"
#       }
#     },
#     {
#       "id": "#record-17-of-77460",
#       "label": "Drawing d-e-064",
#       "rdfs:isDefinedBy": "http://opencontext.org/media/0bc963d4-40da-406c-b395-696ea87618be",
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#geo-rec-geom-17-of-77460",
#         "type": "Point",
#         "coordinates": [
#           31.137937830616877,
#           29.97526657483614
#         ]
#       },
#       "properties": {
#         "id": "#rec-17-of-77460",
#         "feature-type": "item record",
#         "uri": "http://opencontext.org/media/0bc963d4-40da-406c-b395-696ea87618be",
#         "href": "https://opencontext.org/media/0bc963d4-40da-406c-b395-696ea87618be",
#         "citation uri": "http://n2t.net/ark:/28722/k2sn0dp45",
#         "label": "Drawing d-e-064",
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx East/Removal 14",
#         "context href": "https://opencontext.org/subjects/37cbe2aa-1877-4eba-b3a5-45c43d13abc9",
#         "early bce/ce": false,
#         "late bce/ce": false,
#         "item category": "Image",
#         "snippet": " was the removal of a small amount of deposits immediately south of the <em>Roman</em> Stairs, between the",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings-B/d-e-064.jpg",
#         "published": "2017-12-23T01:02:01Z",
#         "updated": "2018-03-23T01:02:22Z"
#       }
#     },
#     {
#       "id": "#record-18-of-77460",
#       "label": "2843",
#       "rdfs:isDefinedBy": "http://opencontext.org/media/9409bf05-af66-4314-b78c-dec7d3a58c77",
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#geo-rec-geom-18-of-77460",
#         "type": "Point",
#         "coordinates": [
#           12.719678174242606,
#           41.88768863730048
#         ]
#       },
#       "properties": {
#         "id": "#rec-18-of-77460",
#         "feature-type": "item record",
#         "uri": "http://opencontext.org/media/9409bf05-af66-4314-b78c-dec7d3a58c77",
#         "href": "https://opencontext.org/media/9409bf05-af66-4314-b78c-dec7d3a58c77",
#         "citation uri": false,
#         "label": "2843",
#         "project label": "The Gabii Project",
#         "project href": "https://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd",
#         "context label": "Italy/Gabii/Area B/Unit 1468",
#         "context href": "https://opencontext.org/subjects/fadbab7d-868a-4b20-b9b9-b54f5544d156",
#         "early bce/ce": false,
#         "late bce/ce": false,
#         "item category": "Image",
#         "snippet": " Attachment Priority  High  \n File Attachment Filename 2843.pdf \n \n<em>Roman</em> Republican\nhttp://n2t.net/ark:/99152",
#         "thumbnail": "https://opencontext.org/static/oc/images/icons/3d-noun-37529.png",
#         "published": "2017-06-04T23:33:47Z",
#         "updated": "2018-01-31T08:17:31Z"
#       }
#     },
#     {
#       "id": "#record-19-of-77460",
#       "label": "2709",
#       "rdfs:isDefinedBy": "http://opencontext.org/media/eeee731e-4394-452b-871d-8b82add85ae2",
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#geo-rec-geom-19-of-77460",
#         "type": "Point",
#         "coordinates": [
#           12.719596721093325,
#           41.88778964097052
#         ]
#       },
#       "when": {
#         "id": "#event-rec-when-19-of-77460",
#         "type": "oc-gen:formation-use-life",
#         "start": "-0399",
#         "stop": "0900"
#       },
#       "properties": {
#         "id": "#rec-19-of-77460",
#         "feature-type": "item record",
#         "uri": "http://opencontext.org/media/eeee731e-4394-452b-871d-8b82add85ae2",
#         "href": "https://opencontext.org/media/eeee731e-4394-452b-871d-8b82add85ae2",
#         "citation uri": false,
#         "label": "2709",
#         "project label": "The Gabii Project",
#         "project href": "https://opencontext.org/projects/3585b372-8d2d-436c-9a4c-b5c10fce3ccd",
#         "context label": "Italy/Gabii/Area B/Unit 1321",
#         "context href": "https://opencontext.org/subjects/afe93991-1894-42eb-a1d8-93a3d03dfa6c",
#         "early bce/ce": -400.0,
#         "late bce/ce": 900.0,
#         "item category": "Image",
#         "snippet": "  \n File Attachment Filename 2709.pdf \n \n<em>Roman</em> Republican\nhttp://n2t.net/ark:/99152/p0qhb66mvjk\nTemporal",
#         "thumbnail": "https://opencontext.org/static/oc/images/icons/3d-noun-37529.png",
#         "published": "2017-06-04T23:31:38Z",
#         "updated": "2018-01-31T08:21:34Z"
#       }
#     },
#     {
#       "id": "#record-20-of-77460",
#       "label": "Drawing d-se-001",
#       "rdfs:isDefinedBy": "http://opencontext.org/media/10a6fd7d-e922-407c-91f1-c492b3b1e6ef",
#       "type": "Feature",
#       "category": "oc-api:geo-record",
#       "geometry": {
#         "id": "#geo-rec-geom-20-of-77460",
#         "type": "Point",
#         "coordinates": [
#           31.137930070235992,
#           29.97510631209676
#         ]
#       },
#       "properties": {
#         "id": "#rec-20-of-77460",
#         "feature-type": "item record",
#         "uri": "http://opencontext.org/media/10a6fd7d-e922-407c-91f1-c492b3b1e6ef",
#         "href": "https://opencontext.org/media/10a6fd7d-e922-407c-91f1-c492b3b1e6ef",
#         "citation uri": false,
#         "label": "Drawing d-se-001",
#         "project label": "ARCE Sphinx Project 1979-1983 Archive",
#         "project href": "https://opencontext.org/projects/141e814a-ba2d-4560-879f-80f1afb019e9",
#         "context label": "Egypt/Giza/Sphinx Amphitheater/Sphinx Ditch/Sphinx Southeast/Feature FSEd3",
#         "context href": "https://opencontext.org/subjects/3013a0b2-dfc8-419c-a1ee-23ad344e7d4f",
#         "early bce/ce": false,
#         "late bce/ce": false,
#         "item category": "Image",
#         "snippet": ", south of <em>Roman</em> pavement \n \n Year  \n Resource Type  Drawings  \n Keywords  Bedrock  Depression  Floor",
#         "thumbnail": "https://artiraq.org/static/opencontext/giza-sphinx/thumbs/Drawings/d-se-001.jpg",
#         "published": "2017-12-23T01:04:03Z",
#         "updated": "2018-03-23T01:05:26Z"
#       }
#     }
#   ]
# }

# %% [markdown]
# 11. Finally, export the JSON to as a file.
#
# `import json`
#
# `with open('OCromandata.json', 'w') as outfile:
# json.dump(data, outfile)`

# %%
import json

with open('OCromandata.json', 'w') as outfile:
json.dump(data, outfile)
# Out:
#   File "<ipython-input-14-0c3c4d62158b>", line 4
#     json.dump(data, outfile)
#        ^
# IndentationError: expected an indented block

# %%
import json

# %%
with open('OCromandata.json', 'w') as outfile: json.dump(data, outfile)

# %% [markdown]
# 12. The last things to do are to save this notebook and download it onto your local machine, including your NAME in the filename. Then download the JSON file you just created. Upload both files to your forked repo for this exercise.
